# %%
import pandas as pd
import numpy as np
from scipy import stats
from tqdm import tqdm

# %%
A = pd.read_excel('./Data/가공완료/[따릉이]연도별시각화자료.xlsx', index_col='Unnamed: 0')
B = pd.read_excel('./Data/가공완료/[따릉이]일자별대여건수(2015~).xlsx', index_col='Unnamed: 0')
C = pd.read_excel('./Data/가공완료/[따릉이_확진]일자별증감.xlsx', index_col='Unnamed: 0')
D = pd.read_excel('./Data/가공완료/[백신]서울백신접종자수(월별).xlsx', index_col='Unnamed: 0')
E = pd.read_excel('./Data/가공완료/[코로나]월별_확진자수.xlsx', index_col='월')

# %%
F = pd.read_excel('./Data/가공완료/[따릉이]월별대여건수(2015~).xlsx', index_col='Unnamed: 0')
F_1 = F[-24:]

# %%
G = pd.read_excel('./Data/가공완료/[따릉이]월별고장건수(2015~).xlsx', index_col='Unnamed: 0')
G

# %%
DF_18 = pd.read_csv('./Data/2018따릉이.csv', encoding='utf-8', index_col=0)
DF_19 = pd.read_csv('./Data/2019따릉이.csv', encoding='utf-8', index_col=0)
DF_20 = pd.read_csv('./Data/2020따릉이.csv', encoding='utf-8', index_col=0)
DF_21 = pd.read_csv('./Data/2021따릉이.csv', encoding='utf-8', index_col=0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %% [markdown]
# # 연도x월별 이용패턴
# - 2016.01-2021.12의 공공자전거이용내역데이터 사용
# - 각 연도x월별로 이용건수의 총합에서 증감수로 변환(각 전년도 동월 이용건수를 뺌)
# - matplotlib 이용하여 각 연도x월별 따릉이 이용패턴을 시각화해 보고자함

# %%
import matplotlib.pyplot as plt
from matplotlib import rc, font_manager
rc('font', family = 'malgun gothic')

# %% [markdown]
# ## 그래프 1
# - 연도별 이용건수

# %%
A = A.set_index('index')
A
# Out:
#           2016     2017     2018     2019      2020      2021
# index
# 01       594.0   2702.0   4950.0  16344.0   28391.0   23631.0
# 02       629.0   3077.5   5967.5  17288.5   26540.0   41333.0
# 03      1692.0   6300.0  14914.0  28653.0   47633.0   73254.0
# 04      2930.5  11360.5  25795.5  52991.0   73533.5  110570.0
# 05      3355.0  15488.0  35975.0  74960.0   89149.0  114851.0
# 06      3745.5  19431.0  42401.5  81181.5  100939.5  121406.5
# 07      3985.0  14039.0  38003.0  74259.0   95705.0  113329.0
# 08      6507.0  18392.0  32216.0  67510.0   52904.0  117873.0
# 09     10706.5  30206.5  51865.0  86676.0  108989.5  138434.0
# 10     11290.0  29072.0  49503.0  84368.0   94840.0  116818.0
# 11      5804.0  15091.5  32446.0  47037.0   67009.5   92541.0
# 12      3320.0   6499.0  16579.0  29243.0   40616.0   62218.0

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 2

A.plot()
plt.xlabel('월')
plt.ylabel('이용건수')
plt.legend()
plt.show()

# %% [markdown]
# # 그래프 2_1
# - 연도별 이동시간

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 2

A.iloc[:, -2:].plot()
asdfqwer33.plot()
E_DF.plot.bar()

plt.xlabel('월')
plt.ylabel('확진자수')
plt.legend()
plt.show()

# %% [markdown]
# # 그래프 2_2
# - 연도별 이동거리

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 2

asdfqwer44.plot(c='b')

plt.xlabel('연월')
plt.ylabel('이동거리')
plt.legend()
plt.show()

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 2

asdfqwer44[:12].plot(c='b', label = '2021')
asdfqwer44[12:].plot(c='r', label = '2019')

plt.xlabel('연월')
plt.ylabel('이동거리')
plt.legend()
plt.show()

# %%
bl_asdfqwer55.append(al_asdfqwer55).reset_index()
A[['2021']].reset_index()
# al_asdfqwer55.reset_index()
# Out:
#     index      2021
# 0       0   23631.0
# 1       1   41333.0
# 2       2   73254.0
# 3       3  110570.0
# 4       4  114851.0
# 5       5  121406.5
# 6       6  113329.0
# 7       7  117873.0
# 8       8  138434.0
# 9       9  116818.0
# 10     10   92541.0
# 11     11   62218.0

# %%
AAA = pd.merge(A[['2021']].reset_index(), al_asdfqwer55.reset_index(), how='left', on='index')
AAA = AAA.drop('index', axis=1).set_index('연월')
AAA
# Out:
#              2021         이동거리
# 연월
# 2021-01   23631.0  2702.776479
# 2021-02   41333.0  3071.907882
# 2021-03   73254.0  4657.599303
# 2021-04  110570.0  3357.945282
# 2021-05  114851.0  3382.821900
# 2021-06  121406.5  7545.320899
# 2021-07  113329.0  3136.044659
# 2021-08  117873.0  3159.996711
# 2021-09  138434.0  2891.311835
# 2021-10  116818.0  2608.446187
# 2021-11   92541.0  2172.781467
# 2021-12   62218.0  1824.254425

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 2

# E_DF[:-14].plot.bar()
asdfqwer55.plot(c='b')
# (AAA.iloc[:, -1]*10).plot(c='b')
# AAA.iloc[:, -2].plot()

plt.xlabel('연월')
plt.ylabel('이동거리')
plt.legend()
plt.show()

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 2

E_DF[:-14].plot.bar()
(asdfqwer55.iloc[:12,0]).plot(c='b')
# (AAA.iloc[:, -1]*10).plot(c='b')
# AAA.iloc[:, -2].plot()

plt.xlabel('연월')
plt.ylabel('이동거리')
plt.legend()
plt.show()

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 2

E_DF[:-2].plot.bar()
(asdfqwer55*10).plot(c='b')
# (AAA.iloc[:, -1]*10).plot(c='b')
# AAA.iloc[:, -2].plot()

plt.xlabel('연월')
plt.ylabel('이동거리')
plt.legend()
plt.show()

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 2


# D_DF.plot.bar()
ENV.iloc[:, 1:-1].plot.bar()
(asdfqwer55.iloc[12:,0]*10).plot(c='b')
# (AAA.iloc[:, -1]*10).plot(c='b')
# AAA.iloc[:, -2].plot()

plt.xlabel('연월')
plt.ylabel('이동거리')
plt.legend()
plt.show()

# %%
D_DF = D.copy()
# D_DF = D_DF.set_index('월')
D_DF
# Out:
#          월   1차접종자수   2차접종자수   추가접종자수
# 0  2021-04  24954.0   2418.5      NaN
# 1  2021-05   3197.0  11486.0      NaN
# 2  2021-06  33913.0  21103.5      NaN
# 3  2021-07  14064.0   9381.0      NaN
# 4  2021-08  51342.0  50134.0      NaN
# 5  2021-09  64436.0  61532.0      NaN
# 6  2021-10   9514.0  77503.0    164.0
# 7  2021-11   7192.5  12101.0  19776.0
# 8  2021-12   6700.0   7087.5  89986.0

# %%
E_DF_2 = E_DF[-14:-2].copy()
E_DF_2 = E_DF_2.reset_index()
ENV = pd.merge(E_DF_2, D_DF, how = 'left', on='월')
ENV = ENV.set_index('월')
ENV
# Out:
#            확진자   1차접종자수   2차접종자수   추가접종자수
# 월
# 2021-01   5168      NaN      NaN      NaN
# 2021-02   4083      NaN      NaN      NaN
# 2021-03   3803      NaN      NaN      NaN
# 2021-04   5811  24954.0   2418.5      NaN
# 2021-05   6303   3197.0  11486.0      NaN
# 2021-06   6075  33913.0  21103.5      NaN
# 2021-07  14377  14064.0   9381.0      NaN
# 2021-08  15019  51342.0  50134.0      NaN
# 2021-09  21148  64436.0  61532.0      NaN
# 2021-10  19123   9514.0  77503.0    164.0
# 2021-11  34711   7192.5  12101.0  19776.0
# 2021-12  70977   6700.0   7087.5  89986.0

# %%
ENV2 = pd.merge(bb, D_DF, how = 'left', left_on='연월', right_on='월')
ENV2 = ENV2.set_index('연월').drop('월', axis=1)
ENV2
# Out:
#                 이동거리   1차접종자수   2차접종자수   추가접종자수
# 연월
# 2021-01  2702.776479      NaN      NaN      NaN
# 2021-02  3071.907882      NaN      NaN      NaN
# 2021-03  4657.599303      NaN      NaN      NaN
# 2021-04  3357.945282  24954.0   2418.5      NaN
# 2021-05  3382.821900   3197.0  11486.0      NaN
# 2021-06  7545.320899  33913.0  21103.5      NaN
# 2021-07  3136.044659  14064.0   9381.0      NaN
# 2021-08  3159.996711  51342.0  50134.0      NaN
# 2021-09  2891.311835  64436.0  61532.0      NaN
# 2021-10  2608.446187   9514.0  77503.0    164.0
# 2021-11  2172.781467   7192.5  12101.0  19776.0
# 2021-12  1824.254425   6700.0   7087.5  89986.0

# %%
bb = asdfqwer55[12:].reset_index()
bb
# Out:
#          연월         이동거리
# 0   2021-01  2702.776479
# 1   2021-02  3071.907882
# 2   2021-03  4657.599303
# 3   2021-04  3357.945282
# 4   2021-05  3382.821900
# 5   2021-06  7545.320899
# 6   2021-07  3136.044659
# 7   2021-08  3159.996711
# 8   2021-09  2891.311835
# 9   2021-10  2608.446187
# 10  2021-11  2172.781467
# 11  2021-12  1824.254425

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 2

A.iloc[:, -1].plot()
asdfqwer55[12:].plot()
# A.iloc[:, -1].plot()
E_DF[12:24].plot.bar()

plt.xlabel('월')
plt.ylabel('이동거리')
plt.legend()
plt.show()

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 2

G[-24:].plot()

plt.xlabel('월')
plt.ylabel('고장접수건수')
plt.legend()
plt.show()

# %%
asdfqwer77_1.corr()
# 이동거리증감/ 확진자증감
# Out:
#           이동거리       확진자
# 이동거리  1.000000 -0.142902
# 확진자  -0.142902  1.000000

# %%
al_asdfqwer55 = asdfqwer55[12:].reset_index()
al_E_DF = E_DF[12:24].reset_index()
al_asdfqwer55
# Out:
#          연월         이동거리
# 0   2021-01  2702.776479
# 1   2021-02  3071.907882
# 2   2021-03  4657.599303
# 3   2021-04  3357.945282
# 4   2021-05  3382.821900
# 5   2021-06  7545.320899
# 6   2021-07  3136.044659
# 7   2021-08  3159.996711
# 8   2021-09  2891.311835
# 9   2021-10  2608.446187
# 10  2021-11  2172.781467
# 11  2021-12  1824.254425

# %%
al_E_DF
# Out:
#           월    확진자
# 0   2021-01   5168
# 1   2021-02   4083
# 2   2021-03   3803
# 3   2021-04   5811
# 4   2021-05   6303
# 5   2021-06   6075
# 6   2021-07  14377
# 7   2021-08  15019
# 8   2021-09  21148
# 9   2021-10  19123
# 10  2021-11  34711
# 11  2021-12  70977

# %%
asdfqwer00 = pd.merge(al_asdfqwer55, al_E_DF, how='left', left_on='연월', right_on='월')
asdfqwer00_1 = asdfqwer00.drop('월', axis=1).set_index('연월', drop=True)
# asdfqwer77_1['이동거리'] = robust_scale(asdfqwer77_1['이동거리'])
# asdfqwer77_1['확진자'] = robust_scale(asdfqwer77_1['확진자'])
# asdfqwer77
asdfqwer00_1
# Out:
#                 이동거리    확진자
# 연월
# 2021-01  2702.776479   5168
# 2021-02  3071.907882   4083
# 2021-03  4657.599303   3803
# 2021-04  3357.945282   5811
# 2021-05  3382.821900   6303
# 2021-06  7545.320899   6075
# 2021-07  3136.044659  14377
# 2021-08  3159.996711  15019
# 2021-09  2891.311835  21148
# 2021-10  2608.446187  19123
# 2021-11  2172.781467  34711
# 2021-12  1824.254425  70977

# %%
bl_asdfqwer55 = asdfqwer55[:12].reset_index()
bl_E_DF = E_DF[:12].reset_index()
bl_asdfqwer55
# Out:
#          연월         이동거리
# 0   2020-01  4523.796668
# 1   2020-02  4825.902353
# 2   2020-03  6733.142302
# 3   2020-04  5952.447186
# 4   2020-05  3870.881290
# 5   2020-06  9780.351784
# 6   2020-07  2944.518821
# 7   2020-08   725.609916
# 8   2020-09   983.861150
# 9   2020-10   500.404606
# 10  2020-11   244.427248
# 11  2020-12   352.082058

# %%
asdfqwer000 = pd.merge(bl_asdfqwer55, bl_E_DF, how='left', left_on='연월', right_on='월')
asdfqwer000_1 = asdfqwer000.drop('월', axis=1).set_index('연월', drop=True)
# asdfqwer77_1['이동거리'] = robust_scale(asdfqwer77_1['이동거리'])
# asdfqwer77_1['확진자'] = robust_scale(asdfqwer77_1['확진자'])
# asdfqwer77
asdfqwer000_1
# Out:
#                 이동거리    확진자
# 연월
# 2020-01  4523.796668      0
# 2020-02  4825.902353      0
# 2020-03  6733.142302      0
# 2020-04  5952.447186      7
# 2020-05  3870.881290    228
# 2020-06  9780.351784    451
# 2020-07  2944.518821    288
# 2020-08   725.609916   2267
# 2020-09   983.861150   1424
# 2020-10   500.404606    719
# 2020-11   244.427248   2802
# 2020-12   352.082058  10209

# %%
asdfqwer00_1.corr() # 큰 상관성 // -0.500337
# Out:
#           이동거리       확진자
# 이동거리  1.000000 -0.500337
# 확진자  -0.500337  1.000000

# %%
asdfqwer000_1.corr() # 큰 상관성 //  -0.51116
# Out:
#          이동거리      확진자
# 이동거리  1.00000 -0.51116
# 확진자  -0.51116  1.00000

# %%
Q = bl_asdfqwer55.append(al_asdfqwer55, ignore_index=True)
Q
# Out:
#          연월         이동거리
# 0   2020-01  4523.796668
# 1   2020-02  4825.902353
# 2   2020-03  6733.142302
# 3   2020-04  5952.447186
# 4   2020-05  3870.881290
# 5   2020-06  9780.351784
# 6   2020-07  2944.518821
# 7   2020-08   725.609916
# 8   2020-09   983.861150
# 9   2020-10   500.404606
# 10  2020-11   244.427248
# 11  2020-12   352.082058
# 12  2021-01  2702.776479
# 13  2021-02  3071.907882
# 14  2021-03  4657.599303
# 15  2021-04  3357.945282
# 16  2021-05  3382.821900
# 17  2021-06  7545.320899
# 18  2021-07  3136.044659
# 19  2021-08  3159.996711
# 20  2021-09  2891.311835
# 21  2021-10  2608.446187
# 22  2021-11  2172.781467
# 23  2021-12  1824.254425

# %%
W = bl_E_DF.append(al_E_DF, ignore_index=True)
W
# Out:
#           월    확진자
# 0   2020-01      0
# 1   2020-02      0
# 2   2020-03      0
# 3   2020-04      7
# 4   2020-05    228
# 5   2020-06    451
# 6   2020-07    288
# 7   2020-08   2267
# 8   2020-09   1424
# 9   2020-10    719
# 10  2020-11   2802
# 11  2020-12  10209
# 12  2021-01   5168
# 13  2021-02   4083
# 14  2021-03   3803
# 15  2021-04   5811
# 16  2021-05   6303
# 17  2021-06   6075
# 18  2021-07  14377
# 19  2021-08  15019
# 20  2021-09  21148
# 21  2021-10  19123
# 22  2021-11  34711
# 23  2021-12  70977

# %%
QW = pd.merge(Q, W, how='left', left_on='연월', right_on='월')
QW = QW.drop('월', axis=1)#.set_index('연월', drop=True)
# asdfqwer77_1['이동거리'] = robust_scale(asdfqwer77_1['이동거리'])
# asdfqwer77_1['확진자'] = robust_scale(asdfqwer77_1['확진자'])
# asdfqwer77
QW
# Out:
#          연월         이동거리    확진자
# 0   2020-01  4523.796668      0
# 1   2020-02  4825.902353      0
# 2   2020-03  6733.142302      0
# 3   2020-04  5952.447186      7
# 4   2020-05  3870.881290    228
# 5   2020-06  9780.351784    451
# 6   2020-07  2944.518821    288
# 7   2020-08   725.609916   2267
# 8   2020-09   983.861150   1424
# 9   2020-10   500.404606    719
# 10  2020-11   244.427248   2802
# 11  2020-12   352.082058  10209
# 12  2021-01  2702.776479   5168
# 13  2021-02  3071.907882   4083
# 14  2021-03  4657.599303   3803
# 15  2021-04  3357.945282   5811
# 16  2021-05  3382.821900   6303
# 17  2021-06  7545.320899   6075
# 18  2021-07  3136.044659  14377
# 19  2021-08  3159.996711  15019
# 20  2021-09  2891.311835  21148
# 21  2021-10  2608.446187  19123
# 22  2021-11  2172.781467  34711
# 23  2021-12  1824.254425  70977

# %%
QW_1 = QW.copy()
QW_1 = QW_1.set_index('연월')
QW_1 = QW_1-QW_1.shift()
QW_1 = QW_1.drop('2020-01')
QW_1[11:]
# Out:
#                 이동거리      확진자
# 연월
# 2021-01  2350.694421  -5041.0
# 2021-02   369.131403  -1085.0
# 2021-03  1585.691421   -280.0
# 2021-04 -1299.654021   2008.0
# 2021-05    24.876619    492.0
# 2021-06  4162.498999   -228.0
# 2021-07 -4409.276240   8302.0
# 2021-08    23.952052    642.0
# 2021-09  -268.684876   6129.0
# 2021-10  -282.865648  -2025.0
# 2021-11  -435.664721  15588.0
# 2021-12  -348.527042  36266.0

# %%
QW.corr()
# Out:
#          이동거리      확진자
# 이동거리  1.00000 -0.25338
# 확진자  -0.25338  1.00000

# %%
QW[:12].corr()
# Out:
#          이동거리      확진자
# 이동거리  1.00000 -0.51116
# 확진자  -0.51116  1.00000

# %%
QW[12:].corr()
# Out:
#           이동거리       확진자
# 이동거리  1.000000 -0.500337
# 확진자  -0.500337  1.000000

# %%
F_1 = F_1.reset_index(drop=True)
F_1
# Out:
#           월     대여건수
# 0   2020-01   794162
# 1   2020-02   762274
# 2   2020-03  1533535
# 3   2020-04  2157390
# 4   2020-05  2480330
# 5   2020-06  2770858
# 6   2020-07  2582511
# 7   2020-08  1733973
# 8   2020-09  2811990
# 9   2020-10  2891618
# 10  2020-11  1990070
# 11  2020-12  1196309
# 12  2021-01   812021
# 13  2021-02  1234546
# 14  2021-03  2184228
# 15  2021-04  3043238
# 16  2021-05  2950150
# 17  2021-06  3460407
# 18  2021-07  3377506
# 19  2021-08  3245974
# 20  2021-09  3736657
# 21  2021-10  3445929
# 22  2021-11  2737291
# 23  2021-12  1826746

# %%
QWF = pd.merge(QW, F_1, how='left', left_on='연월', right_on='월')
QWF = QWF.drop('월', axis=1).set_index('연월', drop=True)
# asdfqwer77_1['이동거리'] = robust_scale(asdfqwer77_1['이동거리'])
# asdfqwer77_1['확진자'] = robust_scale(asdfqwer77_1['확진자'])
# asdfqwer77
QWF
# Out:
#                 이동거리    확진자     대여건수
# 연월
# 2020-01  4523.796668      0   794162
# 2020-02  4825.902353      0   762274
# 2020-03  6733.142302      0  1533535
# 2020-04  5952.447186      7  2157390
# 2020-05  3870.881290    228  2480330
# 2020-06  9780.351784    451  2770858
# 2020-07  2944.518821    288  2582511
# 2020-08   725.609916   2267  1733973
# 2020-09   983.861150   1424  2811990
# 2020-10   500.404606    719  2891618
# 2020-11   244.427248   2802  1990070
# 2020-12   352.082058  10209  1196309
# 2021-01  2702.776479   5168   812021
# 2021-02  3071.907882   4083  1234546
# 2021-03  4657.599303   3803  2184228
# 2021-04  3357.945282   5811  3043238
# 2021-05  3382.821900   6303  2950150
# 2021-06  7545.320899   6075  3460407
# 2021-07  3136.044659  14377  3377506
# 2021-08  3159.996711  15019  3245974
# 2021-09  2891.311835  21148  3736657
# 2021-10  2608.446187  19123  3445929
# 2021-11  2172.781467  34711  2737291
# 2021-12  1824.254425  70977  1826746

# %%
QWF.corr()
# Out:
#           이동거리       확진자      대여건수
# 이동거리  1.000000 -0.253380  0.062958
# 확진자  -0.253380  1.000000  0.149193
# 대여건수  0.062958  0.149193  1.000000

# %%
QWF = QWF.reset_index()
QWF
# Out:
#          연월         이동거리    확진자     대여건수
# 0   2020-01  4523.796668      0   794162
# 1   2020-02  4825.902353      0   762274
# 2   2020-03  6733.142302      0  1533535
# 3   2020-04  5952.447186      7  2157390
# 4   2020-05  3870.881290    228  2480330
# 5   2020-06  9780.351784    451  2770858
# 6   2020-07  2944.518821    288  2582511
# 7   2020-08   725.609916   2267  1733973
# 8   2020-09   983.861150   1424  2811990
# 9   2020-10   500.404606    719  2891618
# 10  2020-11   244.427248   2802  1990070
# 11  2020-12   352.082058  10209  1196309
# 12  2021-01  2702.776479   5168   812021
# 13  2021-02  3071.907882   4083  1234546
# 14  2021-03  4657.599303   3803  2184228
# 15  2021-04  3357.945282   5811  3043238
# 16  2021-05  3382.821900   6303  2950150
# 17  2021-06  7545.320899   6075  3460407
# 18  2021-07  3136.044659  14377  3377506
# 19  2021-08  3159.996711  15019  3245974
# 20  2021-09  2891.311835  21148  3736657
# 21  2021-10  2608.446187  19123  3445929
# ...

# %%
QWF_1 = QWF.copy()
QWF_1 = QWF_1.set_index('연월')
QWF_1 = QWF_1-QWF_1.shift()
QWF_1 = QWF_1.drop('2020-01')
QWF_1
# Out:
#                 이동거리      확진자       대여건수
# 연월
# 2020-02   302.105685      0.0   -31888.0
# 2020-03  1907.239949      0.0   771261.0
# 2020-04  -780.695116      7.0   623855.0
# 2020-05 -2081.565895    221.0   322940.0
# 2020-06  5909.470493    223.0   290528.0
# 2020-07 -6835.832963   -163.0  -188347.0
# 2020-08 -2218.908905   1979.0  -848538.0
# 2020-09   258.251235   -843.0  1078017.0
# 2020-10  -483.456544   -705.0    79628.0
# 2020-11  -255.977358   2083.0  -901548.0
# 2020-12   107.654810   7407.0  -793761.0
# 2021-01  2350.694421  -5041.0  -384288.0
# 2021-02   369.131403  -1085.0   422525.0
# 2021-03  1585.691421   -280.0   949682.0
# 2021-04 -1299.654021   2008.0   859010.0
# 2021-05    24.876619    492.0   -93088.0
# 2021-06  4162.498999   -228.0   510257.0
# 2021-07 -4409.276240   8302.0   -82901.0
# 2021-08    23.952052    642.0  -131532.0
# 2021-09  -268.684876   6129.0   490683.0
# 2021-10  -282.865648  -2025.0  -290728.0
# 2021-11  -435.664721  15588.0  -708638.0
# ...

# %%
QWF_1[:12].corr()
# Out:
#           이동거리       확진자      대여건수
# 이동거리  1.000000 -0.139360  0.214926
# 확진자  -0.139360  1.000000 -0.409513
# 대여건수  0.214926 -0.409513  1.000000

# %%
QWF_1[12:].corr()
# Out:
#           이동거리       확진자      대여건수
# 이동거리  1.000000 -0.243863  0.298564
# 확진자  -0.243863  1.000000 -0.677411
# 대여건수  0.298564 -0.677411  1.000000

# %%
QWFG = pd.merge(QWF, G, how='left', left_on='연월', right_on='등록일시')
QWFG = QWFG.drop('등록일시', axis=1).set_index('연월', drop=True)
# asdfqwer77_1['이동거리'] = robust_scale(asdfqwer77_1['이동거리'])
# asdfqwer77_1['확진자'] = robust_scale(asdfqwer77_1['확진자'])
# asdfqwer77
QWFG
# Out:
#                 이동거리    확진자     대여건수   고장건수
# 연월
# 2020-01  4523.796668      0   794162   2434
# 2020-02  4825.902353      0   762274   2473
# 2020-03  6733.142302      0  1533535  10730
# 2020-04  5952.447186      7  2157390  12201
# 2020-05  3870.881290    228  2480330   5836
# 2020-06  9780.351784    451  2770858   6222
# 2020-07  2944.518821    288  2582511   6138
# 2020-08   725.609916   2267  1733973   3664
# 2020-09   983.861150   1424  2811990   6944
# 2020-10   500.404606    719  2891618   6661
# 2020-11   244.427248   2802  1990070   3198
# 2020-12   352.082058  10209  1196309   2143
# 2021-01  2702.776479   5168   812021   1408
# 2021-02  3071.907882   4083  1234546   1961
# 2021-03  4657.599303   3803  2184228   4698
# 2021-04  3357.945282   5811  3043238  14380
# 2021-05  3382.821900   6303  2950150  15532
# 2021-06  7545.320899   6075  3460407  17272
# 2021-07  3136.044659  14377  3377506  18495
# 2021-08  3159.996711  15019  3245974  18742
# ...

# %%
QWFG[12:]
# Out:
#                 이동거리    확진자     대여건수   고장건수
# 연월
# 2021-01  2702.776479   5168   812021   1408
# 2021-02  3071.907882   4083  1234546   1961
# 2021-03  4657.599303   3803  2184228   4698
# 2021-04  3357.945282   5811  3043238  14380
# 2021-05  3382.821900   6303  2950150  15532
# 2021-06  7545.320899   6075  3460407  17272
# 2021-07  3136.044659  14377  3377506  18495
# 2021-08  3159.996711  15019  3245974  18742
# 2021-09  2891.311835  21148  3736657  21039
# 2021-10  2608.446187  19123  3445929  17503
# 2021-11  2172.781467  34711  2737291  11778
# 2021-12  1824.254425  70977  1826746   8132

# %%
QWFG_1 = QWFG - QWFG.shift()
QWFG_1 = QWFG_1.drop('2020-01')
QWFG_1
# Out:
#                 이동거리      확진자       대여건수    고장건수
# 연월
# 2020-02   302.105685      0.0   -31888.0    39.0
# 2020-03  1907.239949      0.0   771261.0  8257.0
# 2020-04  -780.695116      7.0   623855.0  1471.0
# 2020-05 -2081.565895    221.0   322940.0 -6365.0
# 2020-06  5909.470493    223.0   290528.0   386.0
# 2020-07 -6835.832963   -163.0  -188347.0   -84.0
# 2020-08 -2218.908905   1979.0  -848538.0 -2474.0
# 2020-09   258.251235   -843.0  1078017.0  3280.0
# 2020-10  -483.456544   -705.0    79628.0  -283.0
# 2020-11  -255.977358   2083.0  -901548.0 -3463.0
# 2020-12   107.654810   7407.0  -793761.0 -1055.0
# 2021-01  2350.694421  -5041.0  -384288.0  -735.0
# 2021-02   369.131403  -1085.0   422525.0   553.0
# 2021-03  1585.691421   -280.0   949682.0  2737.0
# 2021-04 -1299.654021   2008.0   859010.0  9682.0
# 2021-05    24.876619    492.0   -93088.0  1152.0
# 2021-06  4162.498999   -228.0   510257.0  1740.0
# 2021-07 -4409.276240   8302.0   -82901.0  1223.0
# ...

# %%
QWFG[:12].corr()
# Out:
#           이동거리       확진자      대여건수      고장건수
# 이동거리  1.000000 -0.511160 -0.028253  0.430057
# 확진자  -0.511160  1.000000 -0.242813 -0.442423
# 대여건수 -0.028253 -0.242813  1.000000  0.460670
# 고장건수  0.430057 -0.442423  0.460670  1.000000

# %%
QWFG[12:].corr()
# Out:
#           이동거리       확진자      대여건수      고장건수
# 이동거리  1.000000 -0.500337  0.269234  0.154520
# 확진자  -0.500337  1.000000 -0.050314  0.023171
# 대여건수  0.269234 -0.050314  1.000000  0.964400
# 고장건수  0.154520  0.023171  0.964400  1.000000

# %%
QWFG_1[:11].corr()
# Out:
#           이동거리       확진자      대여건수      고장건수
# 이동거리  1.000000  0.025512  0.277601  0.328634
# 확진자   0.025512  1.000000 -0.672215 -0.267027
# 대여건수  0.277601 -0.672215  1.000000  0.591266
# 고장건수  0.328634 -0.267027  0.591266  1.000000

# %%
QWFG_1[11:].corr()
# Out:
#           이동거리       확진자      대여건수      고장건수
# 이동거리  1.000000 -0.316084  0.194509 -0.050209
# 확진자  -0.316084  1.000000 -0.566603 -0.408948
# 대여건수  0.194509 -0.566603  1.000000  0.831749
# 고장건수 -0.050209 -0.408948  0.831749  1.000000

# %%
QWFG_2 = QWFG.iloc[:, :-1].copy()
QWFG_2['대여건수'] = QWFG_2['대여건수']/1000
QWFG_2
# Out:
#                 이동거리    확진자      대여건수
# 연월
# 2020-01  4523.796668      0   794.162
# 2020-02  4825.902353      0   762.274
# 2020-03  6733.142302      0  1533.535
# 2020-04  5952.447186      7  2157.390
# 2020-05  3870.881290    228  2480.330
# 2020-06  9780.351784    451  2770.858
# 2020-07  2944.518821    288  2582.511
# 2020-08   725.609916   2267  1733.973
# 2020-09   983.861150   1424  2811.990
# 2020-10   500.404606    719  2891.618
# 2020-11   244.427248   2802  1990.070
# 2020-12   352.082058  10209  1196.309
# 2021-01  2702.776479   5168   812.021
# 2021-02  3071.907882   4083  1234.546
# 2021-03  4657.599303   3803  2184.228
# 2021-04  3357.945282   5811  3043.238
# 2021-05  3382.821900   6303  2950.150
# 2021-06  7545.320899   6075  3460.407
# 2021-07  3136.044659  14377  3377.506
# 2021-08  3159.996711  15019  3245.974
# 2021-09  2891.311835  21148  3736.657
# 2021-10  2608.446187  19123  3445.929
# 2021-11  2172.781467  34711  2737.291
# ...

# %%
QWFG_2[:12].corr()
# Out:
#           이동거리       확진자      대여건수
# 이동거리  1.000000 -0.511160 -0.028253
# 확진자  -0.511160  1.000000 -0.242813
# 대여건수 -0.028253 -0.242813  1.000000

# %%
QWFG_2[12:].corr()
# Out:
#           이동거리       확진자      대여건수
# 이동거리  1.000000 -0.500337  0.269234
# 확진자  -0.500337  1.000000 -0.050314
# 대여건수  0.269234 -0.050314  1.000000

# %% [markdown]
# # 연도x월별 이용량 변화 시각화
# - 전년 대비 비슷한 곡선을 띄고 있어 각 월별 증가량도 비슷하지 않을까 했으나 제각각으로 식별이 어려움
# - 코로나이전 월별 평균증감건수와 코로나이후 월별 증감건수 비교 그래프(2017~2019 / 2020/ 2021)

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 2

A_DF_BF.plot()
A_DF_AF.plot()

plt.xlabel('월')
plt.xlabel('이용건수')
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 2

plt.plot(A_DF_2, label='코로나이전 평균증감건수')
plt.plot(A_DF_3, label='2020 증감건수')
plt.plot(A_DF_4, label='2021 증감건수')

plt.xlabel('월')
plt.xlabel('이용건수')
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# - 코로나이전 대비 이용건수 증감을 스케일처리하여 각각 그래프로 표현

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 5

plt.plot(A_DF_2_sc, alpha = 0.1, label='코로나이전 평균증감건수')
plt.plot(A_DF_3_sc, label='2020 이용건수')

plt.xlabel('월')
plt.ylabel('월별증감비율')
plt.legend()
plt.show()

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 5

plt.plot(A_DF_2_sc, alpha = 0.1, label='코로나이전 평균증감건수')
plt.plot(A_DF_4_sc, label='2021 이용건수')

plt.xlabel('월')
plt.ylabel('월별증감비율')
plt.legend()
plt.show()

# %% [markdown]
# ## 위 그래프에서 코로나 이전 패턴과 다른 부분 확인
# - 2020-01(-) : 서울에서 확진자 발생시작된 시기
# - 2020-07(-) : 사회적 거리두기 (20-06-28) 시작
# - 2020-12(-) : 확진자수 급증 (처음 그래프확인)
# - 2021-04~06 (-) : 확진자수 증가시기
# - 2021-07 (+) : 백신접종시작
# - 2021-08~10(-) : 확진자수 급증시기

# %% [markdown]
# # ====================================

# %% [markdown]
# ## 2020-02 코로나 확진자 발생시기부터 기간별 분석
# ### 차이가 나타나는 기간별로 나눠서 보려고 함
# - 2020.08 (20.06~20.10)
# - 2020.12 ~ 2021.01 (20.10 _ 21.02)
# - 2021.07~ (21.06 _ 21.10)

# %%
E_DF
# Out:
#             확진자
# 월
# 2020-01       0
# 2020-02       0
# 2020-03       0
# 2020-04       7
# 2020-05     228
# 2020-06     451
# 2020-07     288
# 2020-08    2267
# 2020-09    1424
# 2020-10     719
# 2020-11    2802
# 2020-12   10209
# 2021-01    5168
# 2021-02    4083
# 2021-03    3803
# 2021-04    5811
# 2021-05    6303
# 2021-06    6075
# 2021-07   14377
# 2021-08   15019
# 2021-09   21148
# 2021-10   19123
# 2021-11   34711
# 2021-12   70977
# 2022-01   52140
# 2022-02  133097

# %%
B = pd.read_excel('./Data/가공완료/[따릉이]월별대여건수(2015~).xlsx', index_col='Unnamed: 0')
B_DF = B[-23:].set_index('월')
B_DF = B_DF/100
B_DF
# Out:
#              대여건수
# 월
# 2020-02   7622.74
# 2020-03  15335.35
# 2020-04  21573.90
# 2020-05  24803.30
# 2020-06  27708.58
# 2020-07  25825.11
# 2020-08  17339.73
# 2020-09  28119.90
# 2020-10  28916.18
# 2020-11  19900.70
# 2020-12  11963.09
# 2021-01   8120.21
# 2021-02  12345.46
# 2021-03  21842.28
# 2021-04  30432.38
# 2021-05  29501.50
# 2021-06  34604.07
# 2021-07  33775.06
# 2021-08  32459.74
# 2021-09  37366.57
# 2021-10  34459.29
# 2021-11  27372.91
# 2021-12  18267.46

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 5

E_DF[1:24].plot.bar()
plt.plot(B_DF, label='2020-2021월별이용건수', c = 'b')

plt.xlabel('월')
plt.ylabel('확진자수')

plt.legend()
plt.show()

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 5

E_DF[1:24].plot.bar()
plt.plot(E_A_DF_34, label='2020-2021월별이용건수', c = 'b')

plt.xlabel('월')
plt.ylabel('확진자수')

plt.legend()
plt.show()

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 5

E_DF.plot.bar()
plt.plot(asdfqwer22*10, label='월별이동거리', c = 'b')

plt.xlabel('월')
plt.ylabel('확진자수')

plt.legend()
plt.show()

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 5

plt.plot(asdfqwer22*10, label='월별이동거리', c = 'b')

plt.xlabel('월')
plt.ylabel('확진자수')

plt.legend()
plt.show()

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 5

plt.plot(asdfqwer33*10, label='월별이동거리', c = 'b')

plt.xlabel('월')
plt.ylabel('이동거리')

plt.legend()
plt.show()

# %% [markdown]
# # ====================================

# %% [markdown]
# ## 2021-04 코로나 백신접종시기부터 기간별 분석
# ### 차이가 나타나는 기간별로 나눠서 보려고 함

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 5

E_DF.plot.bar()
plt.plot(E_A_DF_34, label='2020-2021월별이용건수', c = 'b')

plt.xlabel('월')
plt.ylabel('확진자수')

plt.legend()
plt.show()

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 5

E_DF_BF.plot.bar()
plt.plot(E_A_DF_34_BF, label='2020-2021월별이용건수', c = 'b')

E_DF_AF.plot.bar()
plt.plot(E_A_DF_34_AF, label='2020-2021월별이용건수', c = 'b')

D_DF.plot.bar()
plt.plot(D_A_DF_34, label='2020-2021월별이용건수', c = 'b')

plt.xlabel('월')
plt.ylabel('확진자수')

plt.legend()
plt.show()

# %% [markdown]
# ### 기간별로 나눴지만, 월별로는 분석에 어려움이 있음
# ### 자세하게 보기 위해 일별분석의 방법으로 진행하려고 함

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 5

plt.plot(DF_18_2_m)

plt.xlabel('2018년 - 월')
plt.ylabel('변수별 연간비율')

plt.legend(['이용건수','이동시간','이동거리'])
plt.show()

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 5

plt.plot(DF_19_2_m)

plt.xlabel('2019년 - 월')
plt.ylabel('변수별 연간비율')

plt.legend(['이용건수','이동시간','이동거리'])
plt.show()

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 5

E_DF_BF.plot.bar()
plt.plot(DF_20_2_mo)

plt.xlabel('2020년 - 월')
plt.ylabel('변수별 연간비율')

plt.legend(['이동시간','이동거리'])
plt.show()

# %% [markdown]
# # ## 2020-07월 부터 유의미한 변화 발견
# - 2020-07월 사회적 거리두기의 영향으로 7~8월에 걸쳐 크게 이용건수가 줄어들었으나
# - 곧 이전년도들 수준으로 이용건수는 늘어나 큰 영향은 없어보였다
# - 하지만 실제 이동거리비율을 보면 이용건수비율에 비하여 크게 밑돌고 있다

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 5

E_DF_AF.plot.bar()
plt.plot(DF_21_2_mo)

plt.xlabel('2021년 - 월')
plt.ylabel('변수별 연간비율')

plt.legend(['이동시간','이동거리'])
plt.show()

# %% [markdown]
# # ## 2021-06월 이후 유의미한 변화 발견
# - 2021-07월부터 백신시작의 영향으로 이용건수 대비 이용시간및거리가 크게 증가
# - 그러나 2021-07월부터 급격하게 코로나 확진자 수 증가 양상
# - 백신접종의 기대감으로 선반영된 2021-06월수치와 확진자수증가에 의해 실제이용시간및거리비율은 낮음

# %% [markdown]
# # ====================================

# %% [markdown]
# - 따릉이 이용건수,시간,거리 숫자 vs 확진자 수

# %% [markdown]
# # 확진자발생수와 이동거리의 상관관계 분석

# %%
co_20 = DF_20_2_mo.merge(E_DF_BF, how= 'left', on='월')
co_21 = DF_21_2_mo.merge(E_DF_AF, how= 'left', on='월')
co_20

# %% [markdown]
# - 따릉이 이용건수,시간,거리 숫자 vs 확진자 수

# %%
co_20_out = co_20.corr()
co_20_out

# %%
co_21_out = co_21.corr()
co_21_out

# %% [markdown]
# - 따릉이 이용건수,시간,거리 숫자 vs 확진자 수(robust scale)

# %%
co_20_out = co_20.corr()
co_20_out

# %%
co_21_out = co_21.corr()
co_21_out

# %% [markdown]
# ## 어쨌든 확진자발생수와 이동거리간에는 비교적 큰 음의 상관관계가 있다
# - 대여소별로 알아보고자 함(은 어렵고, 일단 주어진 관계 해석 진행(예정)
# - 확진자-이동거리 예측모델 만들어보기(예정)

# %% [markdown]
# # ====================================

# %% [markdown]
# # 선형회귀분석

# %%
from sklearn.linear_model import LinearRegression

# %%
C_DF_y2021[['대여일자','확진자증감']]

# %%
x = co_21.drop('이동거리', axis=1)
y = co_21['이동거리']

# %%
reg = LinearRegression()
reg.fit(X, Y)

# %%
X_pred = reg.predict(X)
X_pred

# %%
def get_nmae(pred, y):
    nmae = np.mean(abs(pred-y)/y)
    return nmae

# %%
get_nmae(X_pred, Y)

# %% [markdown]
# - 선형회귀 당췌 뭔소린지...노이해

# %%
XX[12:]
# Out:
#                 이동거리     대여건수    확진자
# 연월
# 2021-01  2702.776479   812021   5168
# 2021-02  3071.907882  1234546   4083
# 2021-03  4657.599303  2184228   3803
# 2021-04  3357.945282  3043238   5811
# 2021-05  3382.821900  2950150   6303
# 2021-06  7545.320899  3460407   6075
# 2021-07  3136.044659  3377506  14377
# 2021-08  3159.996711  3245974  15019
# 2021-09  2891.311835  3736657  21148
# 2021-10  2608.446187  3445929  19123
# 2021-11  2172.781467  2737291  34711
# 2021-12  1824.254425  1826746  70977

# %%
sns.lmplot('확진자', '이동거리', QW[12:])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # SVM

# %%
from sklearn import svm

# %%
SVM = svm.LinearSVC()
SVM
# Out:
# LinearSVC()

# %%
SVM.fit(TRANS[['확진자', '대여건수']], TRANS['이동거리'])
# Out:
# LinearSVC()

# %%
SVM.predict([[0, 1]]) # 확진자가 줄고 대여건수가 늘면 이동거리는 늘어남
# Out:
# array([1.])

# %%
SVM.predict([[1, 0]]) # 확진자가 늘고 대여건수가 줄면 이동거리는 줄어듦
# Out:
# array([0.])

# %%
SVM.predict([[1, 1]]) # 확진자가 늘고 대여건수가 늘면 이동거리는 줄어듦
# Out:
# array([0.])

# %%
SVM.predict([[0, 0]]) # 확진자가 줄고 대여건수가 줄면 이동거리는 늘어남
# Out:
# array([1.])

# %%
print(SVM.coef_[0])
print(SVM.intercept_[0])
# Out:
# [-0.3689529   0.17182757]
# 0.11251821524889405

# %%
print(TG.coef_[0])
print(TG.intercept_[0])
# Out:
# [-0.36894742  0.17182981]
# 0.1125203360973398

# %% [markdown]
# # @@@@@@@ 테스트/트레인 데이터 정제하기

# %%
asdfqwer_a = pd.merge(asdfqwer, qwerasdf, how='left', on='대여일자')
asdfqwer_a

# %%
asdfqwer_a.info()

# %%
asdfqwer_b = asdfqwer_a.copy()
for i in tqdm(range(len(asdfqwer_b))):
    if asdfqwer_b['이용건수'][i] < 0:
        asdfqwer_b['이용건수'][i] = 0
    else:
        asdfqwer_b['이용건수'][i] = 1

    if asdfqwer_b['이동시간'][i] < 0:
        asdfqwer_b['이동시간'][i] = 0
    else:
        asdfqwer_b['이동시간'][i] = 1

    if asdfqwer_b['이동거리'][i] < 0:
        asdfqwer_b['이동거리'][i] = 0
    else:
        asdfqwer_b['이동거리'][i] = 1

    if asdfqwer_b['확진자증감'][i] < 0:
        asdfqwer_b['확진자증감'][i] = 0
    else:
        asdfqwer_b['확진자증감'][i] = 1
asdfqwer_b

# %%
asdfqwer_b.loc[:, ['이용건수','이동시간','이동거리','확진자증감']] = asdfqwer_b.loc[:, ['이용건수','이동시간','이동거리','확진자증감']].astype('int')
asdfqwer_b.info()

# %%
asdfqwer_b_A = asdfqwer_b[['이용건수','이동시간','확진자증감','이동거리']]
X = asdfqwer_b_A.drop('이동거리', axis=1)
Y = asdfqwer_b_A['이동거리']

# %%
asdfqwer_b_A.iloc[:, :3]
# 일단 지금보니까 0,1 로만 나누면 안될듯 어차피 나눈거 범위별로해서 나눠보기루

# %%
QWFG_2 = QWFG_1.copy()
for i in tqdm(range(len(QWFG_2))):
    if QWFG_2['이동거리'][i] < 0:
        QWFG_2['이동거리'][i] = 0
    else:
        QWFG_2['이동거리'][i] = 1

    if QWFG_2['대여건수'][i] < 0:
        QWFG_2['대여건수'][i] = 0
    else:
        QWFG_2['대여건수'][i] = 1

    if QWFG_2['고장건수'][i] < 0:
        QWFG_2['고장건수'][i] = 0
    else:
        QWFG_2['고장건수'][i] = 1

    if QWFG_2['확진자'][i] < 0:
        QWFG_2['확진자'][i] = 0
    else:
        QWFG_2['확진자'][i] = 1
QWFG_2
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 3292.57it/s]
#          이동거리  확진자  대여건수  고장건수
# 연월
# 2020-02   1.0  1.0   0.0   1.0
# 2020-03   1.0  1.0   1.0   1.0
# 2020-04   0.0  1.0   1.0   1.0
# 2020-05   0.0  1.0   1.0   0.0
# 2020-06   1.0  1.0   1.0   1.0
# 2020-07   0.0  0.0   0.0   0.0
# 2020-08   0.0  1.0   0.0   0.0
# 2020-09   1.0  0.0   1.0   1.0
# 2020-10   0.0  0.0   1.0   0.0
# 2020-11   0.0  1.0   0.0   0.0
# 2020-12   1.0  1.0   0.0   0.0
# 2021-01   1.0  0.0   0.0   0.0
# 2021-02   1.0  0.0   1.0   1.0
# 2021-03   1.0  0.0   1.0   1.0
# 2021-04   0.0  1.0   1.0   1.0
# 2021-05   1.0  1.0   0.0   1.0
# 2021-06   1.0  0.0   1.0   1.0
# 2021-07   0.0  1.0   0.0   1.0
# 2021-08   1.0  1.0   0.0   1.0
# 2021-09   0.0  1.0   1.0   1.0
# 2021-10   0.0  0.0   0.0   0.0
# 2021-11   0.0  1.0   0.0   0.0
# 2021-12   0.0  1.0   0.0   0.0

# %%
QWFG_2[11:]
# Out:
#          이동거리  확진자  대여건수  고장건수
# 연월
# 2021-01   1.0  0.0   0.0   0.0
# 2021-02   1.0  0.0   1.0   1.0
# 2021-03   1.0  0.0   1.0   1.0
# 2021-04   0.0  1.0   1.0   1.0
# 2021-05   1.0  1.0   0.0   1.0
# 2021-06   1.0  0.0   1.0   1.0
# 2021-07   0.0  1.0   0.0   1.0
# 2021-08   1.0  1.0   0.0   1.0
# 2021-09   0.0  1.0   1.0   1.0
# 2021-10   0.0  0.0   0.0   0.0
# 2021-11   0.0  1.0   0.0   0.0
# 2021-12   0.0  1.0   0.0   0.0

# %%
TRANS = QWFG_2.iloc[:, :-1].copy()
TRANS
# Out:
#          이동거리  확진자  대여건수
# 연월
# 2020-02   1.0  1.0   0.0
# 2020-03   1.0  1.0   1.0
# 2020-04   0.0  1.0   1.0
# 2020-05   0.0  1.0   1.0
# 2020-06   1.0  1.0   1.0
# 2020-07   0.0  0.0   0.0
# 2020-08   0.0  1.0   0.0
# 2020-09   1.0  0.0   1.0
# 2020-10   0.0  0.0   1.0
# 2020-11   0.0  1.0   0.0
# 2020-12   1.0  1.0   0.0
# 2021-01   1.0  0.0   0.0
# 2021-02   1.0  0.0   1.0
# 2021-03   1.0  0.0   1.0
# 2021-04   0.0  1.0   1.0
# 2021-05   1.0  1.0   0.0
# 2021-06   1.0  0.0   1.0
# 2021-07   0.0  1.0   0.0
# 2021-08   1.0  1.0   0.0
# 2021-09   0.0  1.0   1.0
# 2021-10   0.0  0.0   0.0
# 2021-11   0.0  1.0   0.0
# 2021-12   0.0  1.0   0.0

# %%
XX.iloc[1:, 1:3]
# Out:
#             대여건수    확진자
# 연월
# 2020-02   762274      0
# 2020-03  1533535      0
# 2020-04  2157390      7
# 2020-05  2480330    228
# 2020-06  2770858    451
# 2020-07  2582511    288
# 2020-08  1733973   2267
# 2020-09  2811990   1424
# 2020-10  2891618    719
# 2020-11  1990070   2802
# 2020-12  1196309  10209
# 2021-01   812021   5168
# 2021-02  1234546   4083
# 2021-03  2184228   3803
# 2021-04  3043238   5811
# 2021-05  2950150   6303
# 2021-06  3460407   6075
# 2021-07  3377506  14377
# 2021-08  3245974  15019
# 2021-09  3736657  21148
# 2021-10  3445929  19123
# 2021-11  2737291  34711
# 2021-12  1826746  70977

# %% [markdown]
# # @@@@@@@@@@@@@@@@@@@@@@@@나이브베이지안으로 분류

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.model_selection import train_test_split

# %%
G_model = GaussianNB()

# %%
M_model = MultinomialNB()
M_model
# Out:
# MultinomialNB()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(asdfqwer_b_A.iloc[:, :3], asdfqwer_b_A['이동거리'], test_size=0.33)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(QWFG_2[['대여건수', '확진자']], QWFG_2['이동거리'], test_size=0.33)

# %%
DATA = QWF.copy()
DATA = DATA.set_index('연월')
DATA = DATA.iloc[:, 1:]
DATA
# Out:
#            확진자     대여건수
# 연월
# 2020-01      0   794162
# 2020-02      0   762274
# 2020-03      0  1533535
# 2020-04      7  2157390
# 2020-05    228  2480330
# 2020-06    451  2770858
# 2020-07    288  2582511
# 2020-08   2267  1733973
# 2020-09   1424  2811990
# 2020-10    719  2891618
# 2020-11   2802  1990070
# 2020-12  10209  1196309
# 2021-01   5168   812021
# 2021-02   4083  1234546
# 2021-03   3803  2184228
# 2021-04   5811  3043238
# 2021-05   6303  2950150
# 2021-06   6075  3460407
# 2021-07  14377  3377506
# 2021-08  15019  3245974
# 2021-09  21148  3736657
# 2021-10  19123  3445929
# 2021-11  34711  2737291
# 2021-12  70977  1826746

# %%
X_train, X_test, Y_train, Y_test = train_test_split(DATA[1:], TRANS['이동거리'], test_size=0.33)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(QWFG_2[['확진자', '대여건수']], TRANS['이동거리'], test_size=0.33)

# %%
G_model.fit(X_train, Y_train)
# Out:
# GaussianNB()

# %%
M_model.fit(X_train, Y_train)
# Out:
# MultinomialNB()

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(Y_test, M_model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.67      0.67         3
#          1.0       0.80      0.80      0.80         5
#
#     accuracy                           0.75         8
#    macro avg       0.73      0.73      0.73         8
# weighted avg       0.75      0.75      0.75         8

# %%
print(confusion_matrix(Y_test, M_model.predict(X_test)))
# Out:
# [[2 1]
#  [1 4]]

# %%
M_model.predict([1,1])

# %% [markdown]
# # 의사결정트리로 예측

# %%
from sklearn import tree

# %%
DT = tree.DecisionTreeClassifier()
DT
# Out:
# DecisionTreeClassifier()

# %%
DT.fit(TRANS[['확진자','대여건수']], TRANS['이동거리'])
# Out:
# DecisionTreeClassifier()

# %%
DT.predict([[0,1]]) # 확진자가 줄고 대여건수가 늘면 이동거리는 늘어남
# Out:
# array([1.])

# %%
DT.predict([[1,0]]) # 확진자가 늘고 대여건수가 줄면 이동거리는 줄어듦
# Out:
# array([0.])

# %%
DT.predict([[1,1]]) # 확진자가 늘고 대여건수가 늘면 이동거리는 줄어듦
# Out:
# array([0.])

# %%
DT.predict([[0,0]]) # 확진자가 줄고 대여건수가 줄면 이동거리는 줄어듦
# Out:
# array([0.])

# %%
X = QWF[['이동거리', '대여건수', '연월']].set_index('연월')
X_1 = X.reset_index()

# %%
Y = QWF[['확진자','연월']].set_index('연월')
Y_1 = Y.reset_index()

# %%
XX = pd.merge(X_1, Y_1, how='left', on='연월').set_index('연월')
XX
# Out:
#                 이동거리     대여건수    확진자
# 연월
# 2020-01  4523.796668   794162      0
# 2020-02  4825.902353   762274      0
# 2020-03  6733.142302  1533535      0
# 2020-04  5952.447186  2157390      7
# 2020-05  3870.881290  2480330    228
# 2020-06  9780.351784  2770858    451
# 2020-07  2944.518821  2582511    288
# 2020-08   725.609916  1733973   2267
# 2020-09   983.861150  2811990   1424
# 2020-10   500.404606  2891618    719
# 2020-11   244.427248  1990070   2802
# 2020-12   352.082058  1196309  10209
# 2021-01  2702.776479   812021   5168
# 2021-02  3071.907882  1234546   4083
# 2021-03  4657.599303  2184228   3803
# 2021-04  3357.945282  3043238   5811
# 2021-05  3382.821900  2950150   6303
# 2021-06  7545.320899  3460407   6075
# 2021-07  3136.044659  3377506  14377
# 2021-08  3159.996711  3245974  15019
# 2021-09  2891.311835  3736657  21148
# 2021-10  2608.446187  3445929  19123
# 2021-11  2172.781467  2737291  34711
# 2021-12  1824.254425  1826746  70977

# %%
XX.to_excel('./Data/가공완료/거리,건수,확진자(2020-21).xlsx')

# %% [markdown]
# # k-means

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters = 4)

# %%
kmeans.fit(XX)
# Out:
# KMeans(n_clusters=4)

# %%
y_kmeans = kmeans.predict(XX)

# %%
print(y_kmeans)
# Out:
# [0 0 3 3 1 1 1 3 1 1 3 0 0 0 3 1 1 2 2 2 2 2 1 3]

# %%
Q = Q.set_index('연월')

# %%
W = W.set_index('월')

# %%
W[:12]
# Out:
#            확진자
# 월
# 2020-01      0
# 2020-02      0
# 2020-03      0
# 2020-04      7
# 2020-05    228
# 2020-06    451
# 2020-07    288
# 2020-08   2267
# 2020-09   1424
# 2020-10    719
# 2020-11   2802
# 2020-12  10209

# %%
stats.ttest_rel(Q[:12],W[:12])
# Out:
# Ttest_relResult(statistic=array([1.28692662]), pvalue=array([0.22454184]))

# %%
stats.ttest_rel(Q[12:],W[12:])
# Out:
# Ttest_relResult(statistic=array([1.70344485]), pvalue=array([0.11653527]))

# %%
stats.ttest_rel(Q[4:],W[4:])
# Out:
# Ttest_relResult(statistic=array([-2.15201373]), pvalue=array([0.0444653]))

# %% [markdown]
# # @@@@@데이터별 수정작업@@@@@

# %%
A_DF = A.copy()
B_DF = B.copy()
C_DF = C.copy()
D_DF = D.copy()
E_DF = E.copy()

# %%
DF_18_1 = DF_18.copy()
DF_19_1 = DF_19.copy()
DF_20_1 = DF_20.copy()
DF_21_1 = DF_21.copy()

# %% [markdown]
# # A 관련 변수정리

# %%
# 증감수 = 당해건수- 전년건수
A_DF['월'] = ['01','02','03','04','05','06','07','08','09','10','11','12']
A_DF = A_DF.set_index('월', drop=True)
# A_DF = A_DF.T
# A_DF = A_DF-A_DF.shift()
# A_DF = A_DF.T
# A_DF = A_DF.drop('2016', axis=1)
A_DF
# Out:
#        2017     2018     2019      2020      2021
# 월
# 01   2702.0   4950.0  16344.0   28391.0   23631.0
# 02   3077.5   5967.5  17288.5   26540.0   41333.0
# 03   6300.0  14914.0  28653.0   47633.0   73254.0
# 04  11360.5  25795.5  52991.0   73533.5  110570.0
# 05  15488.0  35975.0  74960.0   89149.0  114851.0
# 06  19431.0  42401.5  81181.5  100939.5  121406.5
# 07  14039.0  38003.0  74259.0   95705.0  113329.0
# 08  18392.0  32216.0  67510.0   52904.0  117873.0
# 09  30206.5  51865.0  86676.0  108989.5  138434.0
# 10  29072.0  49503.0  84368.0   94840.0  116818.0
# 11  15091.5  32446.0  47037.0   67009.5   92541.0
# 12   6499.0  16579.0  29243.0   40616.0   62218.0

# %%
# 증감수 코로나 이전 / 이후
A_DF_BF = A_DF.iloc[:, :3]
A_DF_AF = A_DF.iloc[:, 3:]

# %%
# 증감수 평균
A_DF_2 = A_DF.copy()
A_DF_2['월'] =  ['01','02','03','04','05','06','07','08','09','10','11','12']
A_DF_2 = A_DF_2.set_index('월', drop=True)
A_DF_2 = A_DF_2.iloc[:, :3]
A_DF_2 = pd.DataFrame(A_DF_2.mean(axis=1))
A_DF_2
# Out:
#                0
# 월
# 01   5250.000000
# 02   5553.166667
# 03   8987.000000
# 04  16686.833333
# 05  23868.333333
# 06  25812.000000
# 07  23424.666667
# 08  20334.333333
# 09  25323.166667
# 10  24359.333333
# 11  13744.333333
# 12   8641.000000

# %%
# 코로나이후 2020 증감수
A_DF_3 = A_DF.copy()
A_DF_3['월'] =  ['01','02','03','04','05','06','07','08','09','10','11','12']
A_DF_3 = A_DF_3.set_index('월', drop=True)
A_DF_3 = A_DF_3.iloc[:, -2]
# A_DF_3.sum(axis=1)
A_DF_3 = pd.DataFrame(A_DF_3)
A_DF_3
# Out:
#        2020
# 월
# 01  12047.0
# 02   9251.5
# 03  18980.0
# 04  20542.5
# 05  14189.0
# 06  19758.0
# 07  21446.0
# 08 -14606.0
# 09  22313.5
# 10  10472.0
# 11  19972.5
# 12  11373.0

# %%
# 코로나이후 2021 증감수
A_DF_4 = A_DF.copy()
A_DF_4['월'] =  ['01','02','03','04','05','06','07','08','09','10','11','12']
A_DF_4 = A_DF_4.set_index('월', drop=True)
A_DF_4 = A_DF_4.iloc[:, -1]
A_DF_4 = pd.DataFrame(A_DF_4)
A_DF_4
# Out:
#        2021
# 월
# 01  -4760.0
# 02  14793.0
# 03  25621.0
# 04  37036.5
# 05  25702.0
# 06  20467.0
# 07  17624.0
# 08  64969.0
# 09  29444.5
# 10  21978.0
# 11  25531.5
# 12  21602.0

# %%
# 코로나이전/ 2020/ 2021 각 연도별 스케일링
from sklearn.preprocessing import minmax_scale
A_DF_2_sc = minmax_scale(A_DF_2)
A_DF_3_sc = minmax_scale(A_DF_3)
A_DF_4_sc = minmax_scale(A_DF_4)

# %% [markdown]
# # E 관련 변수정리

# %%
E_DF = E_DF[:-2]
E_DF
# Out:
#            확진자
# 월
# 2020-01      0
# 2020-02      0
# 2020-03      0
# 2020-04      7
# 2020-05    228
# 2020-06    451
# 2020-07    288
# 2020-08   2267
# 2020-09   1424
# 2020-10    719
# 2020-11   2802
# 2020-12  10209
# 2021-01   5168
# 2021-02   4083
# 2021-03   3803
# 2021-04   5811
# 2021-05   6303
# 2021-06   6075
# 2021-07  14377
# 2021-08  15019
# 2021-09  21148
# 2021-10  19123
# 2021-11  34711
# 2021-12  70977

# %%
E_DF_BF = E_DF[:11]
E_DF_AF = E_DF[11:]
E_DF_BF
# Out:
#           확진자
# 월
# 2020-01     0
# 2020-02     0
# 2020-03     0
# 2020-04     7
# 2020-05   228
# 2020-06   451
# 2020-07   288
# 2020-08  2267
# 2020-09  1424
# 2020-10   719
# 2020-11  2802

# %%
E_DF_BF['확진자'] = minmax_scale(E_DF_BF['확진자'])
E_DF_AF['확진자'] = minmax_scale(E_DF_AF['확진자'])
# Out:
# C:\Users\sec\AppData\Local\Temp\ipykernel_9572\4096193014.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   E_DF_BF['확진자'] = minmax_scale(E_DF_BF['확진자'])
# C:\Users\sec\AppData\Local\Temp\ipykernel_9572\4096193014.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   E_DF_AF['확진자'] = minmax_scale(E_DF_AF['확진자'])

# %%
from sklearn.preprocessing import robust_scale
E_DF_BF['확진자'] = robust_scale(E_DF_BF['확진자'])
E_DF_AF['확진자'] = robust_scale(E_DF_AF['확진자'])
# Out:
# C:\Users\sec\AppData\Local\Temp\ipykernel_9572\222280701.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   E_DF_BF['확진자'] = robust_scale(E_DF_BF['확진자'])
# C:\Users\sec\AppData\Local\Temp\ipykernel_9572\222280701.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   E_DF_AF['확진자'] = robust_scale(E_DF_AF['확진자'])

# %%
A_DF_00 = A_DF.copy()
A_DF_00 = A_DF_00.reset_index()
A_DF_0020 = A_DF_00[['월', '2020']]
A_DF_0021 = A_DF_00[['월', '2021']]
A_DF_0021
# Out:
#      월      2021
# 0   01   23631.0
# 1   02   41333.0
# 2   03   73254.0
# 3   04  110570.0
# 4   05  114851.0
# 5   06  121406.5
# 6   07  113329.0
# 7   08  117873.0
# 8   09  138434.0
# 9   10  116818.0
# 10  11   92541.0
# 11  12   62218.0

# %%
E_A_DF_00 = pd.merge(A_DF_2.reset_index(), A_DF_0020, how='left', on = '월')
E_A_DF_00 = pd.merge(E_A_DF_00, A_DF_0021, how='left', on = '월')
E_A_DF_00.columns = ['월', '평균', '2020', '2021']
E_A_DF_00
# Out:
#      월            평균      2020      2021
# 0   01   5250.000000   28391.0   23631.0
# 1   02   5553.166667   26540.0   41333.0
# 2   03   8987.000000   47633.0   73254.0
# 3   04  16686.833333   73533.5  110570.0
# 4   05  23868.333333   89149.0  114851.0
# 5   06  25812.000000  100939.5  121406.5
# 6   07  23424.666667   95705.0  113329.0
# 7   08  20334.333333   52904.0  117873.0
# 8   09  25323.166667  108989.5  138434.0
# 9   10  24359.333333   94840.0  116818.0
# 10  11  13744.333333   67009.5   92541.0
# 11  12   8641.000000   40616.0   62218.0

# %%
E_A_DF_00['평균대비증감2020'] = E_A_DF_00['2020']
E_A_DF_00['평균대비증감2021'] = E_A_DF_00['2021']
for i in range(12):
    E_A_DF_00['평균대비증감2020'][i] = E_A_DF_00['2020'][i] - E_A_DF_00['평균'][i]
    E_A_DF_00['평균대비증감2021'][i] = E_A_DF_00['2021'][i] - E_A_DF_00['평균'][i]
E_A_DF_00 = E_A_DF_00[['월', '평균','평균대비증감2020','평균대비증감2021']]
E_A_DF_00
# Out:
# C:\Users\sec\AppData\Local\Temp\ipykernel_9572\2405859447.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   E_A_DF_00['평균대비증감2020'][i] = E_A_DF_00['2020'][i] - E_A_DF_00['평균'][i]
# C:\Users\sec\AppData\Local\Temp\ipykernel_9572\2405859447.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   E_A_DF_00['평균대비증감2021'][i] = E_A_DF_00['2021'][i] - E_A_DF_00['평균'][i]
#      월            평균    평균대비증감2020     평균대비증감2021
# 0   01   5250.000000  23141.000000   18381.000000
# 1   02   5553.166667  20986.833333   35779.833333
# 2   03   8987.000000  38646.000000   64267.000000
# ...

# %%
E_A_DF_00 = E_A_DF_00.set_index('월')
E_A_DF_00
# Out:
#               평균    평균대비증감2020     평균대비증감2021
# 월
# 01   5250.000000  23141.000000   18381.000000
# 02   5553.166667  20986.833333   35779.833333
# 03   8987.000000  38646.000000   64267.000000
# 04  16686.833333  56846.666667   93883.166667
# 05  23868.333333  65280.666667   90982.666667
# 06  25812.000000  75127.500000   95594.500000
# 07  23424.666667  72280.333333   89904.333333
# 08  20334.333333  32569.666667   97538.666667
# 09  25323.166667  83666.333333  113110.833333
# 10  24359.333333  70480.666667   92458.666667
# 11  13744.333333  53265.166667   78796.666667
# 12   8641.000000  31975.000000   53577.000000

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 2

E_A_DF_00.plot()
plt.xlabel('월')
plt.ylabel('이용건수')
plt.legend()
plt.show()

# %%
E_A_DF_34 = A_DF_3['2020'].append(A_DF_4['2021'], ignore_index=True)
E_A_DF_34 = pd.DataFrame(E_A_DF_34)#.shift()
E_A_DF_34.columns = ['2020-2021월별이용건수']
E_A_DF_34['월'] = ['2020-01','2020-02','2020-03','2020-04','2020-05','2020-06',
                  '2020-07','2020-08','2020-09','2020-10','2020-11','2020-12',
                  '2021-01','2021-02','2021-03','2021-04','2021-05','2021-06',
                  '2021-07','2021-08','2021-09','2021-10','2021-11','2021-12']
E_A_DF_34 = E_A_DF_34.set_index('월')
E_A_DF_34 = E_A_DF_34[1:]
E_A_DF_34
# Out:
#          2020-2021월별이용건수
# 월
# 2020-02           9251.5
# 2020-03          18980.0
# 2020-04          20542.5
# 2020-05          14189.0
# 2020-06          19758.0
# 2020-07          21446.0
# 2020-08         -14606.0
# 2020-09          22313.5
# 2020-10          10472.0
# 2020-11          19972.5
# 2020-12          11373.0
# 2021-01          -4760.0
# 2021-02          14793.0
# 2021-03          25621.0
# 2021-04          37036.5
# 2021-05          25702.0
# 2021-06          20467.0
# 2021-07          17624.0
# 2021-08          64969.0
# 2021-09          29444.5
# 2021-10          21978.0
# 2021-11          25531.5
# 2021-12          21602.0

# %%
E_A_DF_34_BF = E_A_DF_34[:11]
E_A_DF_34_AF = E_A_DF_34[11:]
E_A_DF_34_BF
# Out:
#          2020-2021월별이용건수
# 월
# 2020-02           9251.5
# 2020-03          18980.0
# 2020-04          20542.5
# 2020-05          14189.0
# 2020-06          19758.0
# 2020-07          21446.0
# 2020-08         -14606.0
# 2020-09          22313.5
# 2020-10          10472.0
# 2020-11          19972.5
# 2020-12          11373.0

# %% [markdown]
# # D 관련 변수정리

# %%
D_DF = D_DF.set_index('월')
D_DF

# %%
D_A_DF_34 = A_DF_3['2020'].append(A_DF_4['2021'], ignore_index=True)
D_A_DF_34 = pd.DataFrame(D_A_DF_34)#.shift()
D_A_DF_34.columns = ['2020-2021월별이용건수']
D_A_DF_34['월'] = ['2020-01','2020-02','2020-03','2020-04','2020-05','2020-06',
                  '2020-07','2020-08','2020-09','2020-10','2020-11','2020-12',
                  '2021-01','2021-02','2021-03','2021-04','2021-05','2021-06',
                  '2021-07','2021-08','2021-09','2021-10','2021-11','2021-12']
D_A_DF_34 = D_A_DF_34.set_index('월')
D_A_DF_34 = D_A_DF_34[-9:]
D_A_DF_34

# %% [markdown]
# # C 관련 변수정리

# %%
C_DF

# %%
C_DF_y2021 = C_DF[0:365][['대여일자','증감','확진자증감']].reset_index(drop=True)
C_DF_y2020 = C_DF[365:731][['대여일자','증감','확진자증감']].reset_index(drop=True)
C_DF_y2019 = C_DF[731:1095][['대여일자','증감','확진자증감']].reset_index(drop=True)
C_DF_y2018 = C_DF[1095:1460][['대여일자','증감','확진자증감']].reset_index(drop=True)
C_DF_y2017 = C_DF[1460:1825][['대여일자','증감','확진자증감']].reset_index(drop=True)
C_DF_y2016 = C_DF[1825:2191][['대여일자','증감','확진자증감']].reset_index(drop=True)
C_DF_y2020

# %%
qwerasdf = pd.concat([C_DF_y2018,C_DF_y2019,C_DF_y2020,C_DF_y2021], ignore_index=True)
qwerasdf

# %% [markdown]
# # DF_18192021

# %%
# DF_18_2 = DF_18_1.groupby('대여일자')['이용건수'].sum()
# DF_19_2 = DF_19_1.groupby('대여일자')['이용건수'].sum()
# DF_20_2 = DF_20_1.groupby('대여일자')['이용건수'].sum()
# DF_21_2 = DF_21_1.groupby('대여일자')['이용건수'].sum()

# DF_18_2 = pd.DataFrame(DF_18_2)
# DF_19_2 = pd.DataFrame(DF_19_2)
# DF_20_2 = pd.DataFrame(DF_20_2)
# DF_21_2 = pd.DataFrame(DF_21_2)

DF_18_2 = DF_18_1.groupby('대여일자')['이동시간', '이동거리'].mean()
DF_19_2 = DF_19_1.groupby('대여일자')['이동시간', '이동거리'].mean()
DF_20_2 = DF_20_1.groupby('대여일자')['이동시간', '이동거리'].mean()
DF_21_2 = DF_21_1.groupby('대여일자')['이동시간', '이동거리'].mean()

# DF_18_2[['이동시간','이동거리']] = DF_18_3[['이동시간','이동거리']]
# DF_19_2[['이동시간','이동거리']] = DF_19_3[['이동시간','이동거리']]
# DF_20_2[['이동시간','이동거리']] = DF_20_3[['이동시간','이동거리']]
# DF_21_2[['이동시간','이동거리']] = DF_21_3[['이동시간','이동거리']]

# DF_18_2 = DF_18_2.reset_index()
# DF_19_2 = DF_19_2.reset_index()
# DF_20_2 = DF_20_2.reset_index()
# DF_21_2 = DF_21_2.reset_index()

DF_21_2
# Out:
# C:\Users\sec\AppData\Local\Temp\ipykernel_6176\3281308384.py:11: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   DF_18_2 = DF_18_1.groupby('대여일자')['이동시간', '이동거리'].mean()
# C:\Users\sec\AppData\Local\Temp\ipykernel_6176\3281308384.py:12: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   DF_19_2 = DF_19_1.groupby('대여일자')['이동시간', '이동거리'].mean()
# C:\Users\sec\AppData\Local\Temp\ipykernel_6176\3281308384.py:13: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   DF_20_2 = DF_20_1.groupby('대여일자')['이동시간', '이동거리'].mean()
# C:\Users\sec\AppData\Local\Temp\ipykernel_6176\3281308384.py:14: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# ...

# %%
DF_18_2 = DF_18_2.reset_index()
DF_19_2 = DF_19_2.reset_index()
DF_20_2 = DF_20_2.reset_index()
DF_21_2 = DF_21_2.reset_index()
DF_21_2
# Out:
#            대여일자       이동시간         이동거리
# 0    2021-01-01  33.338011  2232.126114
# 1    2021-01-02  30.978947  2007.048264
# 2    2021-01-03  30.089267  2003.521799
# 3    2021-01-04  25.107849  1757.327474
# 4    2021-01-05  22.979726  2618.655487
# ..          ...        ...          ...
# 359  2021-12-27  18.449606  1651.365560
# 360  2021-12-28  19.300005  1746.377647
# 361  2021-12-29  20.154119  1735.331171
# 362  2021-12-30  19.449430  1733.679767
# 363  2021-12-31  19.023674  1597.423406
#
# [364 rows x 3 columns]

# %%
DF_18_2.to_excel('./Data/2018따릉이(월별이동시간거리).xlsx')
DF_19_2.to_excel('./Data/2019따릉이(월별이동시간거리).xlsx')

DF_20_2.to_excel('./Data/2020따릉이(월별이동시간거리).xlsx')
DF_21_2.to_excel('./Data/2021따릉이(월별이동시간거리).xlsx')

# %%
DF_18_3 = DF_18_2.copy()
DF_19_3 = DF_19_2.copy()
DF_20_3 = DF_20_2.copy()
DF_21_3 = DF_21_2.copy()

# %%
# asdfqwer = pd.DataFrame()
asdfqwer = pd.concat([DF_18_3, DF_19_3, DF_20_3, DF_21_3], ignore_index=True)
asdfqwer.iloc[:,1:-1] = asdfqwer.iloc[:,1:-1]-asdfqwer.iloc[:,1:-1].shift()
asdfqwer = asdfqwer.drop(0, axis=0).reset_index(drop=True)
asdfqwer

# %%
# DF_18_me = DF_18_1.groupby('대여일자')['이용건수','이동시간', '이동거리'].mean()
# DF_19_me = DF_19_1.groupby('대여일자')['이용건수','이동시간', '이동거리'].mean()
# DF_20_me = DF_20_1.groupby('대여일자')['이용건수','이동시간', '이동거리'].mean()
# DF_21_me = DF_21_1.groupby('대여일자')['이용건수','이동시간', '이동거리'].mean()

# DF_18_me = DF_18_me.reset_index()
# DF_19_me = DF_19_me.reset_index()
# DF_20_me = DF_20_me.reset_index()
# DF_21_me = DF_21_me.reset_index()

# DF_21_me

# %%
DF_18_2['월'] = DF_18_2['대여일자']
for i in range(len(DF_18_2)):
    DF_18_2['월'][i] = DF_18_2['대여일자'][i][:7]
DF_19_2['월'] = DF_19_2['대여일자']
for i in range(len(DF_19_2)):
    DF_19_2['월'][i] = DF_19_2['대여일자'][i][:7]
DF_20_2['월'] = DF_20_2['대여일자']
for i in range(len(DF_20_2)):
    DF_20_2['월'][i] = DF_20_2['대여일자'][i][:7]
DF_21_2['월'] = DF_21_2['대여일자']
for i in range(len(DF_21_2)):
    DF_21_2['월'][i] = DF_21_2['대여일자'][i][:7]
# Out:
# C:\Users\sec\AppData\Local\Temp\ipykernel_6176\706541180.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF_18_2['월'][i] = DF_18_2['대여일자'][i][:7]
# C:\Users\sec\AppData\Local\Temp\ipykernel_6176\706541180.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF_19_2['월'][i] = DF_19_2['대여일자'][i][:7]
# C:\Users\sec\AppData\Local\Temp\ipykernel_6176\706541180.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
DF_21_2
# Out:
#               이동시간         이동거리
# 월
# 2021-01  26.042049  2702.776479
# 2021-02  26.743419  3071.907882
# 2021-03  61.623086  4657.599303
# 2021-04  28.979545  3357.945282
# 2021-05  28.186706  3382.821900
# 2021-06  68.120965  7545.320899
# 2021-07  26.626168  3136.044659
# 2021-08  27.919751  3159.996711
# 2021-09  29.053105  2891.311835
# 2021-10  26.392339  2608.446187
# 2021-11  22.906988  2172.781467
# 2021-12  20.682065  1824.254425

# %%
# DF_18_me['월'] = DF_18_me['대여일자']
# for i in range(len(DF_18_me)):
#     DF_18_me['월'][i] = DF_18_me['대여일자'][i][:7]
# DF_19_me['월'] = DF_19_me['대여일자']
# for i in range(len(DF_19_me)):
#     DF_19_me['월'][i] = DF_19_me['대여일자'][i][:7]
# DF_20_me['월'] = DF_20_me['대여일자']
# for i in range(len(DF_20_me)):
#     DF_20_me['월'][i] = DF_20_me['대여일자'][i][:7]
# DF_21_me['월'] = DF_21_me['대여일자']
# for i in range(len(DF_21_me)):
#     DF_21_me['월'][i] = DF_21_me['대여일자'][i][:7]

# %%
DF_18_2 = DF_18_2.groupby('월')[['이동시간','이동거리']].median()
DF_19_2 = DF_19_2.groupby('월')[['이동시간','이동거리']].median()
DF_20_2 = DF_20_2.groupby('월')[['이동시간','이동거리']].median()
DF_21_2 = DF_21_2.groupby('월')[['이동시간','이동거리']].median()

# %%
DF_18_2 = DF_18_2.groupby('월')[['이용건수','이동시간','이동거리']].median()
DF_19_2 = DF_19_2.groupby('월')[['이용건수','이동시간','이동거리']].median()
DF_20_2 = DF_20_2.groupby('연월')[['이동시간','이동거리']].median()
DF_21_2 = DF_21_2.groupby('연월')[['이동시간','이동거리']].median()
DF_21_2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [50], in <module>
# ----> 1 DF_18_2 = DF_18_2.groupby('월')[['이용건수','이동시간','이동거리']].median()
#       2 DF_19_2 = DF_19_2.groupby('월')[['이용건수','이동시간','이동거리']].median()
#       3 DF_20_2 = DF_20_2.groupby('연월')[['이동시간','이동거리']].median()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py:1538, in DataFrameGroupBy.__getitem__(self, key)
#    1529 if isinstance(key, tuple) and len(key) > 1:
#    1530     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1531     # valid syntax, so don't raise warning
#    1532     warnings.warn(
#    1533         "Indexing with multiple keys (implicitly converted to a tuple "
#    1534         "of keys) will be deprecated, use a list instead.",
#    1535         FutureWarning,
#    1536         stacklevel=2,
#    1537     )
# ...

# %%
# DF_18_me_mo = DF_18_me.groupby('월')[['이용건수','이동시간','이동거리']].median()
# DF_19_me_mo = DF_19_me.groupby('월')[['이용건수','이동시간','이동거리']].median()
# DF_20_me_mo = DF_20_me.groupby('월')[['이용건수','이동시간','이동거리']].median()
# DF_21_me_mo = DF_21_me.groupby('월')[['이용건수','이동시간','이동거리']].median()

# %%
DF_20_2_mo
# Out:
#               이동시간         이동거리
# 연월
# 2020-01  21.683933  4523.796668
# 2020-02  23.629094  4825.902353
# 2020-03  36.923037  6733.142302
# 2020-04  40.855269  5952.447186
# 2020-05  41.336291  3870.881290
# 2020-06  38.410130  9780.351784
# 2020-07  36.534497  2944.518821
# 2020-08  29.753198   725.609916
# 2020-09  39.574032   983.861150
# 2020-10  34.120331   500.404606
# 2020-11  27.771455   244.427248
# 2020-12  25.937168   352.082058

# %%
DF_21_2_mo
# Out:
#               이동시간         이동거리
# 연월
# 2021-01  26.042049  2702.776479
# 2021-02  26.743419  3071.907882
# 2021-03  61.623086  4657.599303
# 2021-04  28.979545  3357.945282
# 2021-05  28.186706  3382.821900
# 2021-06  68.120965  7545.320899
# 2021-07  26.626168  3136.044659
# 2021-08  27.919751  3159.996711
# 2021-09  29.053105  2891.311835
# 2021-10  26.392339  2608.446187
# 2021-11  22.906988  2172.781467
# 2021-12  20.682065  1824.254425

# %%
from sklearn.preprocessing import minmax_scale

# %%
# DF_18_2_mo[['이용건수','이동시간','이동거리']] = minmax_scale(DF_18_2_mo[['이용건수','이동시간','이동거리']])
# DF_19_2_mo[['이용건수','이동시간','이동거리']] = minmax_scale(DF_19_2_mo[['이용건수','이동시간','이동거리']])
# DF_20_2_mo[['이용건수','이동시간','이동거리']] = minmax_scale(DF_20_2_mo[['이용건수','이동시간','이동거리']])
# DF_21_2_mo[['이용건수','이동시간','이동거리']] = minmax_scale(DF_21_2_mo[['이용건수','이동시간','이동거리']])
# DF_21_2_mo

# %%
# DF_18_2_m = DF_18_2.set_index('월').drop('대여일자', axis=1)
# DF_19_2_m = DF_19_2.set_index('월').drop('대여일자', axis=1)
# DF_20_2_m = DF_20_2.set_index('월').drop('대여일자', axis=1)
# DF_21_2_m = DF_21_2.set_index('월').drop('대여일자', axis=1)

# DF_21_2_m

# %% [markdown]
# # 연도별 이동시간, 이동거리 그래프

# %%
DF_18_2 = DF_18_1.groupby('대여일자')[['이동거리']].mean()
DF_19_2 = DF_19_1.groupby('대여일자')[['이동거리']].mean()
DF_20_2 = DF_20_1.groupby('대여일자')[['이동거리']].mean()
DF_21_2 = DF_21_1.groupby('대여일자')[['이동거리']].mean()

# DF_18_2 = pd.DataFrame(DF_18_2)
# DF_19_2 = pd.DataFrame(DF_19_2)
# DF_20_2 = pd.DataFrame(DF_20_2)
# DF_21_2 = pd.DataFrame(DF_21_2)

DF_18_2 = DF_18_2.reset_index()
DF_19_2 = DF_19_2.reset_index()
DF_20_2 = DF_20_2.reset_index()
DF_21_2 = DF_21_2.reset_index()

DF_21_2
# Out:
# C:\Users\sec\AppData\Local\Temp\ipykernel_6176\3830128004.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   DF_18_2 = DF_18_1.groupby('대여일자')['이동시간', '이동거리'].mean()
# C:\Users\sec\AppData\Local\Temp\ipykernel_6176\3830128004.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   DF_19_2 = DF_19_1.groupby('대여일자')['이동시간', '이동거리'].mean()
#            대여일자         이동거리
# 0    2021-01-01  2232.126114
# 1    2021-01-02  2007.048264
# 2    2021-01-03  2003.521799
# 3    2021-01-04  1757.327474
# 4    2021-01-05  2618.655487
# ..          ...          ...
# 359  2021-12-27  1651.365560
# 360  2021-12-28  1746.377647
# 361  2021-12-29  1735.331171
# 362  2021-12-30  1733.679767
# 363  2021-12-31  1597.423406
#
# [364 rows x 2 columns]

# %%
DF_18_2['월'] = DF_18_2['대여일자']
for i in range(len(DF_18_2)):
    DF_18_2['월'][i] = DF_18_2['대여일자'][i][5:7]
DF_19_2['월'] = DF_19_2['대여일자']
for i in range(len(DF_19_2)):
    DF_19_2['월'][i] = DF_19_2['대여일자'][i][5:7]
DF_20_2['월'] = DF_20_2['대여일자']
for i in range(len(DF_20_2)):
    DF_20_2['월'][i] = DF_20_2['대여일자'][i][5:7]
DF_21_2['월'] = DF_21_2['대여일자']
for i in range(len(DF_21_2)):
    DF_21_2['월'][i] = DF_21_2['대여일자'][i][5:7]
# Out:
# C:\Users\sec\AppData\Local\Temp\ipykernel_6176\3483986322.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF_18_2['월'][i] = DF_18_2['대여일자'][i][5:7]
# C:\Users\sec\AppData\Local\Temp\ipykernel_6176\3483986322.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF_19_2['월'][i] = DF_19_2['대여일자'][i][5:7]
# C:\Users\sec\AppData\Local\Temp\ipykernel_6176\3483986322.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
DF_18_2['연월'] = DF_18_2['대여일자']
for i in range(len(DF_18_2)):
    DF_18_2['연월'][i] = DF_18_2['대여일자'][i][:7]
DF_19_2['연월'] = DF_19_2['대여일자']
for i in range(len(DF_19_2)):
    DF_19_2['연월'][i] = DF_19_2['대여일자'][i][:7]
DF_20_2['연월'] = DF_20_2['대여일자']
for i in range(len(DF_20_2)):
    DF_20_2['연월'][i] = DF_20_2['대여일자'][i][:7]
DF_21_2['연월'] = DF_21_2['대여일자']
for i in range(len(DF_21_2)):
    DF_21_2['연월'][i] = DF_21_2['대여일자'][i][:7]
# Out:
# C:\Users\sec\AppData\Local\Temp\ipykernel_6176\936424603.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF_18_2['연월'][i] = DF_18_2['대여일자'][i][:7]
# C:\Users\sec\AppData\Local\Temp\ipykernel_6176\936424603.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF_19_2['연월'][i] = DF_19_2['대여일자'][i][:7]
# C:\Users\sec\AppData\Local\Temp\ipykernel_6176\936424603.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
DF_18_3 = DF_18_2.groupby('월')['이동시간'].mean()
DF_19_3 = DF_19_2.groupby('월')['이동시간'].mean()
DF_20_3 = DF_20_2.groupby('월')['이동시간'].mean()
DF_21_3 = DF_21_2.groupby('월')['이동시간'].mean()

DF_18_3 = pd.DataFrame(DF_18_3)
DF_19_3 = pd.DataFrame(DF_19_3)
DF_20_3 = pd.DataFrame(DF_20_3)
DF_21_3 = pd.DataFrame(DF_21_3)

# DF_18_3 = DF_18_3.reset_index()
# DF_19_3 = DF_19_3.reset_index()
# DF_20_3 = DF_20_3.reset_index()
# DF_21_3 = DF_21_3.reset_index()

DF_21_3
# Out:
#          이동시간
# 월
# 01  15.633333
# 02  17.750000
# 03  36.483871
# 04  18.533333
# 05  17.580645
# 06  39.500000
# 07  15.322581
# 08  16.193548
# 09  18.000000
# 10  15.741935
# 11  13.166667
# 12  11.419355

# %%
asdfqwer = pd.merge(DF_18_3, DF_19_3, how='left', on='월')
asdfqwer.columns = ['이동거리2018','이동거리2019']
asdfqwer = asdfqwer.reset_index()
asdfqwer
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [361], in <module>
# ----> 1 asdfqwer = pd.merge(DF_18_3, DF_19_3, how='left', on='월')
#       2 asdfqwer.columns = ['이동거리2018','이동거리2019']
#       3 asdfqwer = asdfqwer.reset_index()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:106, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      89 @Substitution("\nleft : DataFrame or named Series")
#      90 @Appender(_merge_doc, indents=0)
#      91 def merge(
#    (...)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#     109         how=how,
#     110         on=on,
#     111         left_on=left_on,
#     112         right_on=right_on,
# ...

# %%
asdfqwer1 = pd.merge(asdfqwer, DF_20_3, how='left', on='월')
asdfqwer1.columns = ['월', '이동시간2018', '이동시간2019', '이동시간2020']
asdfqwer1
# Out:
#      월   이동시간2018   이동시간2019   이동시간2020
# 0   01  11.193548  11.241935  12.645161
# 1   02  12.750000  12.107143  13.931034
# 2   03  17.516129  13.612903  23.338710
# 3   04  19.068966  17.800000  26.466667
# 4   05  21.500000  20.290323  26.935484
# 5   06  20.933333  19.766667  23.300000
# 6   07  16.967742  17.548387  21.806452
# 7   08  15.870968  19.633333  19.322581
# 8   09  20.115385  20.103448  26.866667
# 9   10  16.821429  19.064516  22.387097
# 10  11  13.148148  14.666667  16.800000
# 11  12  11.483871  12.258065  15.967742

# %%
asdfqwer2 = pd.merge(asdfqwer1, DF_21_3, how='left', on='월')
asdfqwer2.columns = ['월', '이동시간2018', '이동시간2019', '이동시간2020', '이동시간2021']
asdfqwer2 = asdfqwer2.set_index('월')
asdfqwer2
# Out:
#      이동시간2018   이동시간2019   이동시간2020   이동시간2021
# 월
# 01  11.193548  11.241935  12.645161  15.633333
# 02  12.750000  12.107143  13.931034  17.750000
# 03  17.516129  13.612903  23.338710  36.483871
# 04  19.068966  17.800000  26.466667  18.533333
# 05  21.500000  20.290323  26.935484  17.580645
# 06  20.933333  19.766667  23.300000  39.500000
# 07  16.967742  17.548387  21.806452  15.322581
# 08  15.870968  19.633333  19.322581  16.193548
# 09  20.115385  20.103448  26.866667  18.000000
# 10  16.821429  19.064516  22.387097  15.741935
# 11  13.148148  14.666667  16.800000  13.166667
# 12  11.483871  12.258065  15.967742  11.419355

# %%
DF_18_4 = DF_18_2.groupby('월')['이동거리'].mean()
DF_19_4 = DF_19_2.groupby('월')['이동거리'].mean()
DF_20_4 = DF_20_2.groupby('월')['이동거리'].mean()
DF_21_4 = DF_21_2.groupby('월')['이동거리'].mean()

DF_18_4 = pd.DataFrame(DF_18_4)
DF_19_4 = pd.DataFrame(DF_19_4)
DF_20_4 = pd.DataFrame(DF_20_4)
DF_21_4 = pd.DataFrame(DF_21_4)

# DF_18_3 = DF_18_3.reset_index()
# DF_19_3 = DF_19_3.reset_index()
# DF_20_3 = DF_20_3.reset_index()
# DF_21_3 = DF_21_3.reset_index()

DF_21_4
# Out:
#            이동거리
# 월
# 01  1605.516833
# 02  2004.619821
# 03  2451.912581
# 04  1997.011667
# 05  1970.750484
# 06  3765.791000
# 07  1728.982903
# 08  1653.768226
# 09  1609.446000
# 10  1456.806935
# 11  1272.674167
# 12  1136.331452

# %%
asdfqwer_ = pd.merge(DF_18_4, DF_19_4, how='left', on='월')
asdfqwer_.columns = ['이동거리2018','이동거리2019']
asdfqwer_ = asdfqwer_.reset_index()
asdfqwer_
# Out:
#      월     이동거리2018     이동거리2019
# 0   01  1765.000000  1785.806452
# 1   02  1987.500000  1916.250000
# 2   03  2511.451613  2073.387097
# 3   04  2686.896552  2555.666667
# 4   05  2841.666667  2822.258065
# 5   06  2846.333333  2766.333333
# 6   07  2407.419355  2499.677419
# 7   08  2239.516129  2726.000000
# 8   09  2730.769231  2722.068966
# 9   10  2385.000000  2616.774194
# 10  11  1976.666667  2077.000000
# 11  12  1795.483871  1780.967742

# %%
asdfqwer_1 = pd.merge(asdfqwer_, DF_20_4, how='left', on='월')
asdfqwer_1.columns = ['월', '이동거리2018', '이동거리2019', '이동거리2020']
asdfqwer_1
# Out:
#      월     이동거리2018     이동거리2019     이동거리2020
# 0   01  1765.000000  1785.806452  1829.354839
# 1   02  1987.500000  1916.250000  1965.172414
# 2   03  2511.451613  2073.387097  2691.774194
# 3   04  2686.896552  2555.666667  1559.666667
# 4   05  2841.666667  2822.258065    46.451613
# 5   06  2846.333333  2766.333333     0.000000
# 6   07  2407.419355  2499.677419   847.944516
# 7   08  2239.516129  2726.000000     0.000000
# 8   09  2730.769231  2722.068966     0.000000
# 9   10  2385.000000  2616.774194     0.000000
# 10  11  1976.666667  2077.000000     0.000000
# 11  12  1795.483871  1780.967742    19.136129

# %%
asdfqwer_2.to_excel('./Data/가공완료/연,월별이동거리(2018~21).xlsx')

# %%
asdfqwer_2 = pd.merge(asdfqwer_1, DF_21_4, how='left', on='월')
asdfqwer_2.columns = ['월', '이동거리2018', '이동거리2019', '이동거리2020', '이동거리2021']
asdfqwer_2 = asdfqwer_2.set_index('월')
asdfqwer_2
# Out:
#        이동거리2018     이동거리2019     이동거리2020     이동거리2021
# 월
# 01  1765.000000  1785.806452  1829.354839  1605.516833
# 02  1987.500000  1916.250000  1965.172414  2004.619821
# 03  2511.451613  2073.387097  2691.774194  2451.912581
# 04  2686.896552  2555.666667  1559.666667  1997.011667
# 05  2841.666667  2822.258065    46.451613  1970.750484
# 06  2846.333333  2766.333333     0.000000  3765.791000
# 07  2407.419355  2499.677419   847.944516  1728.982903
# 08  2239.516129  2726.000000     0.000000  1653.768226
# 09  2730.769231  2722.068966     0.000000  1609.446000
# 10  2385.000000  2616.774194     0.000000  1456.806935
# 11  1976.666667  2077.000000     0.000000  1272.674167
# 12  1795.483871  1780.967742    19.136129  1136.331452

# %% [markdown]
# # 코로나이후 따릉이 평균 이동거리

# %%
DF_18_5 = DF_18_2.groupby('연월')['이동시간'].mean()
DF_19_5 = DF_19_2.groupby('연월')['이동시간'].mean()
DF_20_5 = DF_20_2.groupby('연월')['이동시간'].mean()
DF_21_5 = DF_21_2.groupby('연월')['이동시간'].mean()

DF_18_5 = pd.DataFrame(DF_18_5)
DF_19_5 = pd.DataFrame(DF_19_5)
DF_20_5 = pd.DataFrame(DF_20_5)
DF_21_5 = pd.DataFrame(DF_21_5)

# DF_18_3 = DF_18_3.reset_index()
# DF_19_3 = DF_19_3.reset_index()
# DF_20_3 = DF_20_3.reset_index()
# DF_21_3 = DF_21_3.reset_index()

DF_21_5
# Out:
#               이동시간
# 연월
# 2021-01  15.633333
# 2021-02  17.750000
# 2021-03  36.483871
# 2021-04  18.533333
# 2021-05  17.580645
# 2021-06  39.500000
# 2021-07  15.322581
# 2021-08  16.193548
# 2021-09  18.000000
# 2021-10  15.741935
# 2021-11  13.166667
# 2021-12  11.419355

# %%
DF_18_5 = DF_18_5.reset_index()
DF_19_5 = DF_19_5.reset_index()
DF_20_5 = DF_20_5.reset_index()
DF_21_5 = DF_21_5.reset_index()
DF_21_5
# Out:
#          연월       이동시간
# 0   2021-01  15.633333
# 1   2021-02  17.750000
# 2   2021-03  36.483871
# 3   2021-04  18.533333
# 4   2021-05  17.580645
# 5   2021-06  39.500000
# 6   2021-07  15.322581
# 7   2021-08  16.193548
# 8   2021-09  18.000000
# 9   2021-10  15.741935
# 10  2021-11  13.166667
# 11  2021-12  11.419355

# %%
asdfqwer22 = DF_18_5.append(DF_19_5, ignore_index=True)
# asdfqwer22.columns = ['이동거리2018','이동거리2019']
asdfqwer22 = asdfqwer22.set_index('연월', drop=True)
asdfqwer22
# Out:
#               이동시간
# 연월
# 2018-01  11.193548
# 2018-02  12.750000
# 2018-03  17.516129
# 2018-04  19.068966
# 2018-05  21.500000
# 2018-06  20.933333
# 2018-07  16.967742
# 2018-08  15.870968
# 2018-09  20.115385
# 2018-10  16.821429
# 2018-11  13.148148
# 2018-12  11.483871
# 2019-01  11.241935
# 2019-02  12.107143
# 2019-03  13.612903
# 2019-04  17.800000
# 2019-05  20.290323
# 2019-06  19.766667
# 2019-07  17.548387
# 2019-08  19.633333
# 2019-09  20.103448
# 2019-10  19.064516
# 2019-11  14.666667
# 2019-12  12.258065

# %%
asdfqwer33  = DF_20_5.append(DF_21_5, ignore_index=True)
# asdfqwer22.columns = ['이동거리2018','이동거리2019']
asdfqwer33 = asdfqwer33.set_index('연월')
asdfqwer33
# Out:
#               이동시간
# 연월
# 2020-01  12.645161
# 2020-02  13.931034
# 2020-03  23.338710
# 2020-04  26.466667
# 2020-05  26.935484
# 2020-06  23.300000
# 2020-07  21.806452
# 2020-08  19.322581
# 2020-09  26.866667
# 2020-10  22.387097
# 2020-11  16.800000
# 2020-12  15.967742
# 2021-01  15.633333
# 2021-02  17.750000
# 2021-03  36.483871
# 2021-04  18.533333
# 2021-05  17.580645
# 2021-06  39.500000
# 2021-07  15.322581
# 2021-08  16.193548
# 2021-09  18.000000
# 2021-10  15.741935
# 2021-11  13.166667
# 2021-12  11.419355

# %%
DF_18_6 = DF_18_2.groupby('연월')['이동거리'].median()
DF_19_6 = DF_19_2.groupby('연월')['이동거리'].median()
DF_20_6 = DF_20_2.groupby('연월')['이동거리'].median()
DF_21_6 = DF_21_2.groupby('연월')['이동거리'].median()

DF_18_6 = pd.DataFrame(DF_18_6)
DF_19_6 = pd.DataFrame(DF_19_6)
DF_20_6 = pd.DataFrame(DF_20_6)
DF_21_6 = pd.DataFrame(DF_21_6)

# DF_18_3 = DF_18_3.reset_index()
# DF_19_3 = DF_19_3.reset_index()
# DF_20_3 = DF_20_3.reset_index()
# DF_21_3 = DF_21_3.reset_index()

DF_21_6
# Out:
#                 이동거리
# 연월
# 2021-01  2702.776479
# 2021-02  3071.907882
# 2021-03  4657.599303
# 2021-04  3357.945282
# 2021-05  3382.821900
# 2021-06  7545.320899
# 2021-07  3136.044659
# 2021-08  3159.996711
# 2021-09  2891.311835
# 2021-10  2608.446187
# 2021-11  2172.781467
# 2021-12  1824.254425

# %%
DF_18_6 = DF_18_6.reset_index()
DF_19_6 = DF_19_6.reset_index()
DF_20_6 = DF_20_6.reset_index()
DF_21_6 = DF_21_6.reset_index()
DF_21_6
# Out:
#          연월         이동거리
# 0   2021-01  2702.776479
# 1   2021-02  3071.907882
# 2   2021-03  4657.599303
# 3   2021-04  3357.945282
# 4   2021-05  3382.821900
# 5   2021-06  7545.320899
# 6   2021-07  3136.044659
# 7   2021-08  3159.996711
# 8   2021-09  2891.311835
# 9   2021-10  2608.446187
# 10  2021-11  2172.781467
# 11  2021-12  1824.254425

# %%
asdfqwer44 = DF_18_6.append(DF_19_6, ignore_index=True)
# asdfqwer22.columns = ['이동거리2018','이동거리2019']
asdfqwer44 = asdfqwer44.set_index('연월', drop=True)
asdfqwer44
# Out:
#                 이동거리
# 연월
# 2018-01  3170.646120
# 2018-02  3447.652954
# 2018-03  4563.791554
# 2018-04  5162.697875
# 2018-05  5446.438344
# 2018-06  5497.581007
# 2018-07  5168.748023
# 2018-08  4996.684956
# 2018-09  5643.070462
# 2018-10  4856.915624
# 2018-11  4100.622305
# 2018-12  3662.594483
# 2019-01  3601.497698
# 2019-02  3844.995616
# 2019-03  4258.190292
# 2019-04  5384.829446
# 2019-05  6209.611765
# 2019-06  6728.388849
# 2019-07  6745.967917
# 2019-08  6687.262099
# 2019-09  7198.337179
# 2019-10  6860.703792
# 2019-11  5348.002719
# 2019-12  4540.819955

# %%
asdfqwer44_1 = asdfqwer44 - asdfqwer44.shift()
asdfqwer44_1 = asdfqwer44_1.drop('2018-01')
asdfqwer44_1 = asdfqwer44_1.reset_index()
asdfqwer44_1
# Out:
#          연월         이동거리
# 0   2018-02   277.006835
# 1   2018-03  1116.138600
# 2   2018-04   598.906321
# 3   2018-05   283.740469
# 4   2018-06    51.142663
# 5   2018-07  -328.832984
# 6   2018-08  -172.063067
# 7   2018-09   646.385506
# 8   2018-10  -786.154838
# 9   2018-11  -756.293319
# 10  2018-12  -438.027822
# 11  2019-01   -61.096785
# 12  2019-02   243.497918
# 13  2019-03   413.194676
# 14  2019-04  1126.639154
# 15  2019-05   824.782318
# 16  2019-06   518.777084
# 17  2019-07    17.579069
# 18  2019-08   -58.705818
# 19  2019-09   511.075079
# 20  2019-10  -337.633387
# 21  2019-11 -1512.701072
# 22  2019-12  -807.182765

# %%
asdfqwer55  = DF_20_6.append(DF_21_6, ignore_index=True)
# asdfqwer22.columns = ['이동거리2018','이동거리2019']
asdfqwer55 = asdfqwer55.set_index('연월')
asdfqwer55
# Out:
#                 이동거리
# 연월
# 2020-01  4523.796668
# 2020-02  4825.902353
# 2020-03  6733.142302
# 2020-04  5952.447186
# 2020-05  3870.881290
# 2020-06  9780.351784
# 2020-07  2944.518821
# 2020-08   725.609916
# 2020-09   983.861150
# 2020-10   500.404606
# 2020-11   244.427248
# 2020-12   352.082058
# 2021-01  2702.776479
# 2021-02  3071.907882
# 2021-03  4657.599303
# 2021-04  3357.945282
# 2021-05  3382.821900
# 2021-06  7545.320899
# 2021-07  3136.044659
# 2021-08  3159.996711
# 2021-09  2891.311835
# 2021-10  2608.446187
# 2021-11  2172.781467
# 2021-12  1824.254425

# %%
asdfqwer55_1 = asdfqwer55 - asdfqwer55.shift()
asdfqwer55_1 = asdfqwer55_1.drop('2020-01')
asdfqwer55_1
# Out:
#                 이동거리
# 연월
# 2020-02   302.105685
# 2020-03  1907.239949
# 2020-04  -780.695116
# 2020-05 -2081.565895
# 2020-06  5909.470493
# 2020-07 -6835.832963
# 2020-08 -2218.908905
# 2020-09   258.251235
# 2020-10  -483.456544
# 2020-11  -255.977358
# 2020-12   107.654810
# 2021-01  2350.694421
# 2021-02   369.131403
# 2021-03  1585.691421
# 2021-04 -1299.654021
# 2021-05    24.876619
# 2021-06  4162.498999
# 2021-07 -4409.276240
# 2021-08    23.952052
# 2021-09  -268.684876
# 2021-10  -282.865648
# 2021-11  -435.664721
# 2021-12  -348.527042

# %%
asdfqwer55_1 = asdfqwer55_1.reset_index()
asdfqwer55_1
# Out:
#          연월         이동거리
# 0   2020-02   302.105685
# 1   2020-03  1907.239949
# 2   2020-04  -780.695116
# 3   2020-05 -2081.565895
# 4   2020-06  5909.470493
# 5   2020-07 -6835.832963
# 6   2020-08 -2218.908905
# 7   2020-09   258.251235
# 8   2020-10  -483.456544
# 9   2020-11  -255.977358
# 10  2020-12   107.654810
# 11  2021-01  2350.694421
# 12  2021-02   369.131403
# 13  2021-03  1585.691421
# 14  2021-04 -1299.654021
# 15  2021-05    24.876619
# 16  2021-06  4162.498999
# 17  2021-07 -4409.276240
# 18  2021-08    23.952052
# 19  2021-09  -268.684876
# 20  2021-10  -282.865648
# 21  2021-11  -435.664721
# 22  2021-12  -348.527042

# %%
E_DF_1 = E_DF - E_DF.shift()
E_DF_1 = E_DF_1.drop('2020-01')
E_DF_1
# Out:
#              확진자
# 월
# 2020-02      0.0
# 2020-03      0.0
# 2020-04      7.0
# 2020-05    221.0
# 2020-06    223.0
# 2020-07   -163.0
# 2020-08   1979.0
# 2020-09   -843.0
# 2020-10   -705.0
# 2020-11   2083.0
# 2020-12   7407.0
# 2021-01  -5041.0
# 2021-02  -1085.0
# 2021-03   -280.0
# 2021-04   2008.0
# 2021-05    492.0
# 2021-06   -228.0
# 2021-07   8302.0
# 2021-08    642.0
# 2021-09   6129.0
# 2021-10  -2025.0
# 2021-11  15588.0
# 2021-12  36266.0
# 2022-01 -18837.0
# 2022-02  80957.0

# %%
E_DF_1 = E_DF_1.reset_index()
E_DF_1
# Out:
#           월      확진자
# 0   2020-02      0.0
# 1   2020-03      0.0
# 2   2020-04      7.0
# 3   2020-05    221.0
# 4   2020-06    223.0
# 5   2020-07   -163.0
# 6   2020-08   1979.0
# 7   2020-09   -843.0
# 8   2020-10   -705.0
# 9   2020-11   2083.0
# 10  2020-12   7407.0
# 11  2021-01  -5041.0
# 12  2021-02  -1085.0
# 13  2021-03   -280.0
# 14  2021-04   2008.0
# 15  2021-05    492.0
# 16  2021-06   -228.0
# 17  2021-07   8302.0
# 18  2021-08    642.0
# 19  2021-09   6129.0
# 20  2021-10  -2025.0
# 21  2021-11  15588.0
# 22  2021-12  36266.0
# 23  2022-01 -18837.0
# 24  2022-02  80957.0

# %%
from sklearn.preprocessing import minmax_scale, robust_scale

# %%
asdfqwer77 = pd.merge(asdfqwer55_1, E_DF_1, how='left', left_on='연월', right_on='월')
asdfqwer77_1 = asdfqwer77.drop('월', axis=1).set_index('연월', drop=True)
asdfqwer77_1['이동거리'] = robust_scale(asdfqwer77_1['이동거리'])
asdfqwer77_1['확진자'] = robust_scale(asdfqwer77_1['확진자'])
# asdfqwer77
asdfqwer77_1
# Out:
#              이동거리        확진자
# 연월
# 2020-02  0.576714  -0.096108
# 2020-03  2.235434  -0.096108
# 2020-04 -0.542235  -0.093064
# 2020-05 -1.886534   0.000000
# 2020-06  6.371276   0.000870
# 2020-07 -6.799518  -0.166993
# 2020-08 -2.028462   0.764514
# 2020-09  0.531396  -0.462709
# 2020-10 -0.235073  -0.402696
# 2020-11  0.000000   0.809741
# 2020-12  0.375772   3.125027
# 2021-01  2.693693  -2.288324
# 2021-02  0.645977  -0.567950
# 2021-03  1.903151  -0.217873
# 2021-04 -1.078519   0.777125
# 2021-05  0.290230   0.117852
# 2021-06  4.565983  -0.195260
# 2021-07 -4.291953   3.514242
# 2021-08  0.289275   0.183083
# 2021-09 -0.013132   2.569254
# 2021-10 -0.027786  -0.976734
# 2021-11 -0.185686   6.682757
# 2021-12 -0.095639  15.675147
